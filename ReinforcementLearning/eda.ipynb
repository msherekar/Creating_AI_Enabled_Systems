# %% [markdown]
# # LIBRARIES

# %%
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# # DATA

# %%
userbase = pd.read_csv('userbase.csv')
sent = pd.read_csv('sent_emails.csv')
responded = pd.read_csv('responded.csv')

# %%
responded = responded.drop_duplicates()

# %% [markdown]
# # MERGE DATA
# To create environment

# %%
responded.head(1)
# Out:
#   Responded_Date  Customer_ID  SubjectLine_ID
# 0     2016-01-25       217102               3

# %%
merged_data.head(1)
# Out:
#     Sent_Date  Customer_ID  SubjectLine_ID Gender Type          Email_Address  \
# 0  2016-01-28         1413               2      M    B  Jaj2NuUJneD@gmail.com
#
#    Age  Tenure
# 0   44      12

# %%
# sent + userbase
merged_data = pd.merge(sent, userbase, on='Customer_ID', how='left')

# Fill in additional columns based on userbase information
merged_data['Gender'] = merged_data['Gender'].fillna(userbase.set_index('Customer_ID')['Gender'])
merged_data['Type'] = merged_data['Type'].fillna(userbase.set_index('Customer_ID')['Type'])
merged_data['Email_Address'] = merged_data['Email_Address'].fillna(userbase.set_index('Customer_ID')['Email_Address'])
merged_data['Age'] = merged_data['Age'].fillna(userbase.set_index('Customer_ID')['Age'])
merged_data['Tenure'] = merged_data['Tenure'].fillna(userbase.set_index('Customer_ID')['Tenure'])

# Drop rows with missing values
merged_data = merged_data.dropna() # CHECK AGAIN LATER
merged_data.head(5)
# Out:
#     Sent_Date  Customer_ID  SubjectLine_ID Gender Type  \
# 0  2016-01-28         1413               2      M    B
# 1  2016-03-02        83889               2      M    C
# 2  2016-03-09       457832               3      M    C
# 3  2016-01-20       127772               1      M    C
# 4  2016-02-03       192123               3      M    C
#
#              Email_Address  Age  Tenure
# 0    Jaj2NuUJneD@gmail.com   44      12
# 1  Y1Se1qBYrUe@hotmail.com   29      23
# 2            vAF@gmail.com   26      14
# 3         QAWqTT@gmail.com   26      15
# 4           Qtgy0C@msn.com   33       9

# %%
# add responded 
merged_data = pd.merge(merged_data, responded, on=['Customer_ID'], how='left') # meger on responded date as well.

# SANITY CHECK
merged_data.head(1)
# Out:
#     Sent_Date  Customer_ID  SubjectLine_ID_x Gender Type  \
# 0  2016-01-28         1413                 2      M    B
#
#            Email_Address  Age  Tenure Responded_Date  SubjectLine_ID_y
# 0  Jaj2NuUJneD@gmail.com   44      12     2016-01-31               2.0

# %%
# REWARDS
merged_data['Reward'] = np.where(merged_data['Sent_Date'] == merged_data['Responded_Date'], 1, 0)

# Fix missing dates
placeholder_date = pd.to_datetime('1900-01-01') # placeholder date
merged_data['Responded_Date'].fillna(placeholder_date, inplace=True)

# Renaming columns
merged_data.rename(columns={'SubjectLine_ID_x': 'SubLine_Sent'}, inplace=True)
merged_data.rename(columns={'SubjectLine_ID_y': 'SubLine_Responded'}, inplace=True)
merged_data['SubLine_Responded'].fillna(-1, inplace=True)

merged_data.head(1)
# Out:
#     Sent_Date  Customer_ID  SubLine_Sent Gender Type          Email_Address  \
# 0  2016-01-28         1413             2      M    B  Jaj2NuUJneD@gmail.com
#
#    Age  Tenure Responded_Date  SubLine_Responded  Reward
# 0   44      12     2016-01-31                2.0       0

# %% [markdown]
# # STATES

# %%
from itertools import product
states=list(product(merged_data['Gender'].unique(), merged_data['Type'].unique(),merged_data['Age'].unique(), merged_data['Tenure'].unique()))

# %%
# Initialize a dictionary to store rewards for each state
state_rewards = {}

# Iterate over each state
for state in states:
    # Calculate the hash value of the state tuple and get the corresponding index
    state_index = hash(tuple(state)) % len(states)
    
    # Retrieve the reward from the merged_data DataFrame based on the state index
    reward = merged_data.loc[state_index, 'Reward']
    
    # Store the reward in the state_rewards dictionary
    state_rewards[state] = reward
# Out:
# State: ('M', 'B', 44, 12), Reward: 0
# State: ('M', 'B', 44, 23), Reward: 0
# State: ('M', 'B', 44, 14), Reward: 1
# State: ('M', 'B', 44, 15), Reward: 0
# State: ('M', 'B', 44, 9), Reward: 0
# State: ('M', 'B', 44, 21), Reward: 0
# State: ('M', 'B', 44, 11), Reward: 0
# State: ('M', 'B', 44, 25), Reward: 0
# State: ('M', 'B', 44, 8), Reward: 0
# State: ('M', 'B', 44, 27), Reward: 0
# State: ('M', 'B', 44, 18), Reward: 1
# State: ('M', 'B', 44, 32), Reward: 0
# State: ('M', 'B', 44, 5), Reward: 0
# State: ('M', 'B', 44, 20), Reward: 0
# State: ('M', 'B', 44, 10), Reward: 0
# State: ('M', 'B', 44, 13), Reward: 0
# State: ('M', 'B', 44, 24), Reward: 0
# State: ('M', 'B', 44, 7), Reward: 0
# State: ('M', 'B', 44, 22), Reward: 0
# State: ('M', 'B', 44, 17), Reward: 0
# State: ('M', 'B', 44, 28), Reward: 0
# State: ('M', 'B', 44, 6), Reward: 0
# State: ('M', 'B', 44, 19), Reward: 1
# State: ('M', 'B', 44, 26), Reward: 0
# State: ('M', 'B', 44, 16), Reward: 0
# State: ('M', 'B', 44, 30), Reward: 1
# State: ('M', 'B', 44, 4), Reward: 0
# State: ('M', 'B', 44, 2), Reward: 0
# State: ('M', 'B', 44, 31), Reward: 1
# State: ('M', 'B', 44, 3), Reward: 0
# State: ('M', 'B', 44, 29), Reward: 0
# State: ('M', 'B', 44, 33), Reward: 0
# State: ('M', 'B', 44, 34), Reward: 0
# State: ('M', 'B', 44, 1), Reward: 0
# State: ('M', 'B', 44, 35), Reward: 0
# State: ('M', 'B', 44, 0), Reward: 0
# State: ('M', 'B', 44, 36), Reward: 0
# State: ('M', 'B', 44, 38), Reward: 0
# State: ('M', 'B', 29, 12), Reward: 0
# State: ('M', 'B', 29, 23), Reward: 0
# State: ('M', 'B', 29, 14), Reward: 1
# State: ('M', 'B', 29, 15), Reward: 0
# State: ('M', 'B', 29, 9), Reward: 0
# State: ('M', 'B', 29, 21), Reward: 0
# State: ('M', 'B', 29, 11), Reward: 0
# State: ('M', 'B', 29, 25), Reward: 1
# State: ('M', 'B', 29, 8), Reward: 0
# State: ('M', 'B', 29, 27), Reward: 0
# State: ('M', 'B', 29, 18), Reward: 0
# State: ('M', 'B', 29, 32), Reward: 0
# State: ('M', 'B', 29, 5), Reward: 0
# State: ('M', 'B', 29, 20), Reward: 1
# State: ('M', 'B', 29, 10), Reward: 0
# State: ('M', 'B', 29, 13), Reward: 0
# State: ('M', 'B', 29, 24), Reward: 0
# State: ('M', 'B', 29, 7), Reward: 0
# State: ('M', 'B', 29, 22), Reward: 0
# State: ('M', 'B', 29, 17), Reward: 0
# State: ('M', 'B', 29, 28), Reward: 0
# State: ('M', 'B', 29, 6), Reward: 0
# State: ('M', 'B', 29, 19), Reward: 0
# State: ('M', 'B', 29, 26), Reward: 0
# State: ('M', 'B', 29, 16), Reward: 0
# State: ('M', 'B', 29, 30), Reward: 0
# State: ('M', 'B', 29, 4), Reward: 0
# State: ('M', 'B', 29, 2), Reward: 0
# State: ('M', 'B', 29, 31), Reward: 0
# State: ('M', 'B', 29, 3), Reward: 0
# State: ('M', 'B', 29, 29), Reward: 0
# State: ('M', 'B', 29, 33), Reward: 0
# State: ('M', 'B', 29, 34), Reward: 0
# State: ('M', 'B', 29, 1), Reward: 1
# State: ('M', 'B', 29, 35), Reward: 0
# State: ('M', 'B', 29, 0), Reward: 0
# State: ('M', 'B', 29, 36), Reward: 0
# State: ('M', 'B', 29, 38), Reward: 0
# State: ('M', 'B', 26, 12), Reward: 0
# State: ('M', 'B', 26, 23), Reward: 0
# State: ('M', 'B', 26, 14), Reward: 0
# State: ('M', 'B', 26, 15), Reward: 0
# State: ('M', 'B', 26, 9), Reward: 0
# State: ('M', 'B', 26, 21), Reward: 0
# State: ('M', 'B', 26, 11), Reward: 0
# State: ('M', 'B', 26, 25), Reward: 0
# State: ('M', 'B', 26, 8), Reward: 0
# State: ('M', 'B', 26, 27), Reward: 0
# State: ('M', 'B', 26, 18), Reward: 0
# State: ('M', 'B', 26, 32), Reward: 0
# State: ('M', 'B', 26, 5), Reward: 0
# State: ('M', 'B', 26, 20), Reward: 0
# State: ('M', 'B', 26, 10), Reward: 0
# State: ('M', 'B', 26, 13), Reward: 0
# State: ('M', 'B', 26, 24), Reward: 0
# State: ('M', 'B', 26, 7), Reward: 0
# State: ('M', 'B', 26, 22), Reward: 0
# State: ('M', 'B', 26, 17), Reward: 0
# State: ('M', 'B', 26, 28), Reward: 0
# State: ('M', 'B', 26, 6), Reward: 0
# State: ('M', 'B', 26, 19), Reward: 0
# State: ('M', 'B', 26, 26), Reward: 0
# State: ('M', 'B', 26, 16), Reward: 0
# State: ('M', 'B', 26, 30), Reward: 0
# State: ('M', 'B', 26, 4), Reward: 0
# State: ('M', 'B', 26, 2), Reward: 0
# State: ('M', 'B', 26, 31), Reward: 0
# State: ('M', 'B', 26, 3), Reward: 0
# State: ('M', 'B', 26, 29), Reward: 0
# State: ('M', 'B', 26, 33), Reward: 1
# State: ('M', 'B', 26, 34), Reward: 0
# State: ('M', 'B', 26, 1), Reward: 0
# State: ('M', 'B', 26, 35), Reward: 0
# State: ('M', 'B', 26, 0), Reward: 0
# State: ('M', 'B', 26, 36), Reward: 0
# State: ('M', 'B', 26, 38), Reward: 0
# State: ('M', 'B', 33, 12), Reward: 0
# State: ('M', 'B', 33, 23), Reward: 1
# State: ('M', 'B', 33, 14), Reward: 0
# State: ('M', 'B', 33, 15), Reward: 0
# State: ('M', 'B', 33, 9), Reward: 0
# State: ('M', 'B', 33, 21), Reward: 0
# State: ('M', 'B', 33, 11), Reward: 0
# State: ('M', 'B', 33, 25), Reward: 0
# State: ('M', 'B', 33, 8), Reward: 0
# State: ('M', 'B', 33, 27), Reward: 0
# State: ('M', 'B', 33, 18), Reward: 1
# State: ('M', 'B', 33, 32), Reward: 0
# State: ('M', 'B', 33, 5), Reward: 0
# State: ('M', 'B', 33, 20), Reward: 0
# State: ('M', 'B', 33, 10), Reward: 0
# State: ('M', 'B', 33, 13), Reward: 0
# State: ('M', 'B', 33, 24), Reward: 1
# State: ('M', 'B', 33, 7), Reward: 0
# State: ('M', 'B', 33, 22), Reward: 0
# State: ('M', 'B', 33, 17), Reward: 0
# State: ('M', 'B', 33, 28), Reward: 0
# State: ('M', 'B', 33, 6), Reward: 0
# State: ('M', 'B', 33, 19), Reward: 0
# State: ('M', 'B', 33, 26), Reward: 0
# State: ('M', 'B', 33, 16), Reward: 0
# State: ('M', 'B', 33, 30), Reward: 0
# State: ('M', 'B', 33, 4), Reward: 1
# State: ('M', 'B', 33, 2), Reward: 0
# State: ('M', 'B', 33, 31), Reward: 0
# State: ('M', 'B', 33, 3), Reward: 0
# State: ('M', 'B', 33, 29), Reward: 0
# State: ('M', 'B', 33, 33), Reward: 0
# State: ('M', 'B', 33, 34), Reward: 1
# State: ('M', 'B', 33, 1), Reward: 0
# State: ('M', 'B', 33, 35), Reward: 0
# State: ('M', 'B', 33, 0), Reward: 0
# State: ('M', 'B', 33, 36), Reward: 0
# State: ('M', 'B', 33, 38), Reward: 1
# State: ('M', 'B', 34, 12), Reward: 0
# State: ('M', 'B', 34, 23), Reward: 0
# State: ('M', 'B', 34, 14), Reward: 0
# State: ('M', 'B', 34, 15), Reward: 0
# State: ('M', 'B', 34, 9), Reward: 0
# State: ('M', 'B', 34, 21), Reward: 0
# State: ('M', 'B', 34, 11), Reward: 0
# State: ('M', 'B', 34, 25), Reward: 0
# State: ('M', 'B', 34, 8), Reward: 0
# State: ('M', 'B', 34, 27), Reward: 0
# State: ('M', 'B', 34, 18), Reward: 0
# State: ('M', 'B', 34, 32), Reward: 0
# State: ('M', 'B', 34, 5), Reward: 0
# State: ('M', 'B', 34, 20), Reward: 1
# State: ('M', 'B', 34, 10), Reward: 0
# State: ('M', 'B', 34, 13), Reward: 0
# State: ('M', 'B', 34, 24), Reward: 0
# State: ('M', 'B', 34, 7), Reward: 0
# State: ('M', 'B', 34, 22), Reward: 0
# State: ('M', 'B', 34, 17), Reward: 0
# State: ('M', 'B', 34, 28), Reward: 0
# State: ('M', 'B', 34, 6), Reward: 0
# State: ('M', 'B', 34, 19), Reward: 0
# State: ('M', 'B', 34, 26), Reward: 0
# State: ('M', 'B', 34, 16), Reward: 0
# State: ('M', 'B', 34, 30), Reward: 0
# State: ('M', 'B', 34, 4), Reward: 0
# State: ('M', 'B', 34, 2), Reward: 1
# State: ('M', 'B', 34, 31), Reward: 0
# State: ('M', 'B', 34, 3), Reward: 1
# State: ('M', 'B', 34, 29), Reward: 0
# State: ('M', 'B', 34, 33), Reward: 0
# State: ('M', 'B', 34, 34), Reward: 0
# State: ('M', 'B', 34, 1), Reward: 0
# State: ('M', 'B', 34, 35), Reward: 0
# State: ('M', 'B', 34, 0), Reward: 0
# State: ('M', 'B', 34, 36), Reward: 0
# State: ('M', 'B', 34, 38), Reward: 0
# State: ('M', 'B', 35, 12), Reward: 0
# State: ('M', 'B', 35, 23), Reward: 0
# State: ('M', 'B', 35, 14), Reward: 0
# State: ('M', 'B', 35, 15), Reward: 1
# State: ('M', 'B', 35, 9), Reward: 0
# State: ('M', 'B', 35, 21), Reward: 0
# State: ('M', 'B', 35, 11), Reward: 0
# State: ('M', 'B', 35, 25), Reward: 0
# State: ('M', 'B', 35, 8), Reward: 0
# State: ('M', 'B', 35, 27), Reward: 0
# State: ('M', 'B', 35, 18), Reward: 0
# State: ('M', 'B', 35, 32), Reward: 0
# State: ('M', 'B', 35, 5), Reward: 0
# State: ('M', 'B', 35, 20), Reward: 0
# State: ('M', 'B', 35, 10), Reward: 0
# State: ('M', 'B', 35, 13), Reward: 0
# State: ('M', 'B', 35, 24), Reward: 1
# State: ('M', 'B', 35, 7), Reward: 0
# State: ('M', 'B', 35, 22), Reward: 0
# State: ('M', 'B', 35, 17), Reward: 0
# State: ('M', 'B', 35, 28), Reward: 0
# State: ('M', 'B', 35, 6), Reward: 0
# State: ('M', 'B', 35, 19), Reward: 0
# State: ('M', 'B', 35, 26), Reward: 0
# State: ('M', 'B', 35, 16), Reward: 0
# State: ('M', 'B', 35, 30), Reward: 0
# State: ('M', 'B', 35, 4), Reward: 0
# State: ('M', 'B', 35, 2), Reward: 0
# State: ('M', 'B', 35, 31), Reward: 1
# State: ('M', 'B', 35, 3), Reward: 0
# State: ('M', 'B', 35, 29), Reward: 0
# State: ('M', 'B', 35, 33), Reward: 0
# State: ('M', 'B', 35, 34), Reward: 0
# State: ('M', 'B', 35, 1), Reward: 0
# State: ('M', 'B', 35, 35), Reward: 1
# State: ('M', 'B', 35, 0), Reward: 0
# State: ('M', 'B', 35, 36), Reward: 0
# State: ('M', 'B', 35, 38), Reward: 0
# State: ('M', 'B', 41, 12), Reward: 0
# State: ('M', 'B', 41, 23), Reward: 0
# State: ('M', 'B', 41, 14), Reward: 0
# State: ('M', 'B', 41, 15), Reward: 0
# State: ('M', 'B', 41, 9), Reward: 0
# State: ('M', 'B', 41, 21), Reward: 1
# State: ('M', 'B', 41, 11), Reward: 0
# State: ('M', 'B', 41, 25), Reward: 0
# State: ('M', 'B', 41, 8), Reward: 0
# State: ('M', 'B', 41, 27), Reward: 0
# State: ('M', 'B', 41, 18), Reward: 0
# State: ('M', 'B', 41, 32), Reward: 1
# State: ('M', 'B', 41, 5), Reward: 0
# State: ('M', 'B', 41, 20), Reward: 0
# State: ('M', 'B', 41, 10), Reward: 0
# State: ('M', 'B', 41, 13), Reward: 0
# State: ('M', 'B', 41, 24), Reward: 0
# State: ('M', 'B', 41, 7), Reward: 1
# State: ('M', 'B', 41, 22), Reward: 0
# State: ('M', 'B', 41, 17), Reward: 0
# State: ('M', 'B', 41, 28), Reward: 0
# State: ('M', 'B', 41, 6), Reward: 1
# State: ('M', 'B', 41, 19), Reward: 0
# State: ('M', 'B', 41, 26), Reward: 1
# State: ('M', 'B', 41, 16), Reward: 0
# State: ('M', 'B', 41, 30), Reward: 0
# State: ('M', 'B', 41, 4), Reward: 0
# State: ('M', 'B', 41, 2), Reward: 0
# State: ('M', 'B', 41, 31), Reward: 0
# State: ('M', 'B', 41, 3), Reward: 0
# State: ('M', 'B', 41, 29), Reward: 0
# State: ('M', 'B', 41, 33), Reward: 0
# State: ('M', 'B', 41, 34), Reward: 0
# State: ('M', 'B', 41, 1), Reward: 1
# State: ('M', 'B', 41, 35), Reward: 0
# State: ('M', 'B', 41, 0), Reward: 0
# State: ('M', 'B', 41, 36), Reward: 1
# State: ('M', 'B', 41, 38), Reward: 0
# State: ('M', 'B', 27, 12), Reward: 0
# State: ('M', 'B', 27, 23), Reward: 1
# State: ('M', 'B', 27, 14), Reward: 0
# State: ('M', 'B', 27, 15), Reward: 0
# State: ('M', 'B', 27, 9), Reward: 0
# State: ('M', 'B', 27, 21), Reward: 0
# State: ('M', 'B', 27, 11), Reward: 0
# State: ('M', 'B', 27, 25), Reward: 0
# State: ('M', 'B', 27, 8), Reward: 0
# State: ('M', 'B', 27, 27), Reward: 0
# State: ('M', 'B', 27, 18), Reward: 0
# State: ('M', 'B', 27, 32), Reward: 0
# State: ('M', 'B', 27, 5), Reward: 0
# State: ('M', 'B', 27, 20), Reward: 0
# State: ('M', 'B', 27, 10), Reward: 0
# State: ('M', 'B', 27, 13), Reward: 0
# State: ('M', 'B', 27, 24), Reward: 0
# State: ('M', 'B', 27, 7), Reward: 0
# State: ('M', 'B', 27, 22), Reward: 1
# State: ('M', 'B', 27, 17), Reward: 0
# State: ('M', 'B', 27, 28), Reward: 0
# State: ('M', 'B', 27, 6), Reward: 0
# State: ('M', 'B', 27, 19), Reward: 0
# State: ('M', 'B', 27, 26), Reward: 0
# State: ('M', 'B', 27, 16), Reward: 0
# State: ('M', 'B', 27, 30), Reward: 0
# State: ('M', 'B', 27, 4), Reward: 0
# State: ('M', 'B', 27, 2), Reward: 1
# State: ('M', 'B', 27, 31), Reward: 0
# State: ('M', 'B', 27, 3), Reward: 0
# State: ('M', 'B', 27, 29), Reward: 0
# State: ('M', 'B', 27, 33), Reward: 0
# State: ('M', 'B', 27, 34), Reward: 0
# State: ('M', 'B', 27, 1), Reward: 0
# State: ('M', 'B', 27, 35), Reward: 0
# State: ('M', 'B', 27, 0), Reward: 0
# State: ('M', 'B', 27, 36), Reward: 0
# State: ('M', 'B', 27, 38), Reward: 0
# State: ('M', 'B', 39, 12), Reward: 0
# State: ('M', 'B', 39, 23), Reward: 0
# State: ('M', 'B', 39, 14), Reward: 0
# State: ('M', 'B', 39, 15), Reward: 0
# State: ('M', 'B', 39, 9), Reward: 0
# State: ('M', 'B', 39, 21), Reward: 0
# State: ('M', 'B', 39, 11), Reward: 0
# State: ('M', 'B', 39, 25), Reward: 0
# State: ('M', 'B', 39, 8), Reward: 0
# State: ('M', 'B', 39, 27), Reward: 0
# State: ('M', 'B', 39, 18), Reward: 1
# State: ('M', 'B', 39, 32), Reward: 0
# State: ('M', 'B', 39, 5), Reward: 1
# State: ('M', 'B', 39, 20), Reward: 0
# State: ('M', 'B', 39, 10), Reward: 0
# State: ('M', 'B', 39, 13), Reward: 0
# State: ('M', 'B', 39, 24), Reward: 0
# State: ('M', 'B', 39, 7), Reward: 1
# State: ('M', 'B', 39, 22), Reward: 0
# State: ('M', 'B', 39, 17), Reward: 0
# State: ('M', 'B', 39, 28), Reward: 0
# State: ('M', 'B', 39, 6), Reward: 0
# State: ('M', 'B', 39, 19), Reward: 0
# State: ('M', 'B', 39, 26), Reward: 0
# State: ('M', 'B', 39, 16), Reward: 0
# State: ('M', 'B', 39, 30), Reward: 0
# State: ('M', 'B', 39, 4), Reward: 0
# State: ('M', 'B', 39, 2), Reward: 0
# State: ('M', 'B', 39, 31), Reward: 1
# State: ('M', 'B', 39, 3), Reward: 0
# State: ('M', 'B', 39, 29), Reward: 0
# State: ('M', 'B', 39, 33), Reward: 0
# State: ('M', 'B', 39, 34), Reward: 0
# State: ('M', 'B', 39, 1), Reward: 0
# State: ('M', 'B', 39, 35), Reward: 0
# State: ('M', 'B', 39, 0), Reward: 0
# State: ('M', 'B', 39, 36), Reward: 0
# State: ('M', 'B', 39, 38), Reward: 0
# State: ('M', 'B', 36, 12), Reward: 0
# State: ('M', 'B', 36, 23), Reward: 0
# State: ('M', 'B', 36, 14), Reward: 0
# State: ('M', 'B', 36, 15), Reward: 0
# State: ('M', 'B', 36, 9), Reward: 1
# State: ('M', 'B', 36, 21), Reward: 0
# State: ('M', 'B', 36, 11), Reward: 0
# State: ('M', 'B', 36, 25), Reward: 0
# State: ('M', 'B', 36, 8), Reward: 1
# State: ('M', 'B', 36, 27), Reward: 0
# State: ('M', 'B', 36, 18), Reward: 0
# State: ('M', 'B', 36, 32), Reward: 0
# State: ('M', 'B', 36, 5), Reward: 1
# State: ('M', 'B', 36, 20), Reward: 0
# State: ('M', 'B', 36, 10), Reward: 0
# State: ('M', 'B', 36, 13), Reward: 0
# State: ('M', 'B', 36, 24), Reward: 0
# State: ('M', 'B', 36, 7), Reward: 0
# State: ('M', 'B', 36, 22), Reward: 0
# State: ('M', 'B', 36, 17), Reward: 0
# State: ('M', 'B', 36, 28), Reward: 0
# State: ('M', 'B', 36, 6), Reward: 1
# State: ('M', 'B', 36, 19), Reward: 0
# State: ('M', 'B', 36, 26), Reward: 0
# State: ('M', 'B', 36, 16), Reward: 0
# State: ('M', 'B', 36, 30), Reward: 0
# State: ('M', 'B', 36, 4), Reward: 0
# State: ('M', 'B', 36, 2), Reward: 0
# State: ('M', 'B', 36, 31), Reward: 0
# State: ('M', 'B', 36, 3), Reward: 1
# State: ('M', 'B', 36, 29), Reward: 0
# State: ('M', 'B', 36, 33), Reward: 0
# State: ('M', 'B', 36, 34), Reward: 0
# State: ('M', 'B', 36, 1), Reward: 0
# State: ('M', 'B', 36, 35), Reward: 0
# State: ('M', 'B', 36, 0), Reward: 0
# State: ('M', 'B', 36, 36), Reward: 0
# State: ('M', 'B', 36, 38), Reward: 0
# State: ('M', 'B', 30, 12), Reward: 0
# State: ('M', 'B', 30, 23), Reward: 0
# State: ('M', 'B', 30, 14), Reward: 0
# State: ('M', 'B', 30, 15), Reward: 0
# State: ('M', 'B', 30, 9), Reward: 0
# State: ('M', 'B', 30, 21), Reward: 0
# State: ('M', 'B', 30, 11), Reward: 0
# State: ('M', 'B', 30, 25), Reward: 0
# State: ('M', 'B', 30, 8), Reward: 0
# State: ('M', 'B', 30, 27), Reward: 1
# State: ('M', 'B', 30, 18), Reward: 0
# State: ('M', 'B', 30, 32), Reward: 0
# State: ('M', 'B', 30, 5), Reward: 0
# State: ('M', 'B', 30, 20), Reward: 0
# State: ('M', 'B', 30, 10), Reward: 1
# State: ('M', 'B', 30, 13), Reward: 0
# State: ('M', 'B', 30, 24), Reward: 0
# State: ('M', 'B', 30, 7), Reward: 0
# State: ('M', 'B', 30, 22), Reward: 0
# State: ('M', 'B', 30, 17), Reward: 0
# State: ('M', 'B', 30, 28), Reward: 1
# State: ('M', 'B', 30, 6), Reward: 0
# State: ('M', 'B', 30, 19), Reward: 0
# State: ('M', 'B', 30, 26), Reward: 0
# State: ('M', 'B', 30, 16), Reward: 0
# State: ('M', 'B', 30, 30), Reward: 1
# State: ('M', 'B', 30, 4), Reward: 0
# State: ('M', 'B', 30, 2), Reward: 0
# State: ('M', 'B', 30, 31), Reward: 0
# State: ('M', 'B', 30, 3), Reward: 0
# State: ('M', 'B', 30, 29), Reward: 0
# State: ('M', 'B', 30, 33), Reward: 0
# State: ('M', 'B', 30, 34), Reward: 0
# State: ('M', 'B', 30, 1), Reward: 0
# State: ('M', 'B', 30, 35), Reward: 0
# State: ('M', 'B', 30, 0), Reward: 0
# State: ('M', 'B', 30, 36), Reward: 0
# State: ('M', 'B', 30, 38), Reward: 0
# State: ('M', 'B', 40, 12), Reward: 0
# State: ('M', 'B', 40, 23), Reward: 0
# State: ('M', 'B', 40, 14), Reward: 0
# State: ('M', 'B', 40, 15), Reward: 0
# State: ('M', 'B', 40, 9), Reward: 0
# State: ('M', 'B', 40, 21), Reward: 0
# State: ('M', 'B', 40, 11), Reward: 0
# State: ('M', 'B', 40, 25), Reward: 0
# State: ('M', 'B', 40, 8), Reward: 0
# State: ('M', 'B', 40, 27), Reward: 0
# State: ('M', 'B', 40, 18), Reward: 0
# State: ('M', 'B', 40, 32), Reward: 0
# State: ('M', 'B', 40, 5), Reward: 0
# State: ('M', 'B', 40, 20), Reward: 0
# State: ('M', 'B', 40, 10), Reward: 0
# State: ('M', 'B', 40, 13), Reward: 0
# State: ('M', 'B', 40, 24), Reward: 0
# State: ('M', 'B', 40, 7), Reward: 0
# State: ('M', 'B', 40, 22), Reward: 0
# State: ('M', 'B', 40, 17), Reward: 0
# State: ('M', 'B', 40, 28), Reward: 0
# State: ('M', 'B', 40, 6), Reward: 0
# State: ('M', 'B', 40, 19), Reward: 0
# State: ('M', 'B', 40, 26), Reward: 0
# State: ('M', 'B', 40, 16), Reward: 1
# State: ('M', 'B', 40, 30), Reward: 0
# State: ('M', 'B', 40, 4), Reward: 0
# State: ('M', 'B', 40, 2), Reward: 0
# State: ('M', 'B', 40, 31), Reward: 0
# State: ('M', 'B', 40, 3), Reward: 0
# State: ('M', 'B', 40, 29), Reward: 0
# State: ('M', 'B', 40, 33), Reward: 0
# State: ('M', 'B', 40, 34), Reward: 0
# State: ('M', 'B', 40, 1), Reward: 0
# State: ('M', 'B', 40, 35), Reward: 0
# State: ('M', 'B', 40, 0), Reward: 0
# State: ('M', 'B', 40, 36), Reward: 0
# State: ('M', 'B', 40, 38), Reward: 0
# State: ('M', 'B', 28, 12), Reward: 0
# State: ('M', 'B', 28, 23), Reward: 0
# State: ('M', 'B', 28, 14), Reward: 0
# State: ('M', 'B', 28, 15), Reward: 0
# State: ('M', 'B', 28, 9), Reward: 0
# State: ('M', 'B', 28, 21), Reward: 1
# State: ('M', 'B', 28, 11), Reward: 0
# State: ('M', 'B', 28, 25), Reward: 0
# State: ('M', 'B', 28, 8), Reward: 0
# State: ('M', 'B', 28, 27), Reward: 0
# State: ('M', 'B', 28, 18), Reward: 0
# State: ('M', 'B', 28, 32), Reward: 0
# State: ('M', 'B', 28, 5), Reward: 0
# State: ('M', 'B', 28, 20), Reward: 0
# State: ('M', 'B', 28, 10), Reward: 0
# State: ('M', 'B', 28, 13), Reward: 0
# State: ('M', 'B', 28, 24), Reward: 0
# State: ('M', 'B', 28, 7), Reward: 0
# State: ('M', 'B', 28, 22), Reward: 0
# State: ('M', 'B', 28, 17), Reward: 0
# State: ('M', 'B', 28, 28), Reward: 0
# State: ('M', 'B', 28, 6), Reward: 0
# State: ('M', 'B', 28, 19), Reward: 0
# State: ('M', 'B', 28, 26), Reward: 0
# State: ('M', 'B', 28, 16), Reward: 0
# State: ('M', 'B', 28, 30), Reward: 0
# State: ('M', 'B', 28, 4), Reward: 0
# State: ('M', 'B', 28, 2), Reward: 0
# State: ('M', 'B', 28, 31), Reward: 0
# State: ('M', 'B', 28, 3), Reward: 1
# State: ('M', 'B', 28, 29), Reward: 0
# State: ('M', 'B', 28, 33), Reward: 1
# State: ('M', 'B', 28, 34), Reward: 0
# State: ('M', 'B', 28, 1), Reward: 0
# State: ('M', 'B', 28, 35), Reward: 0
# State: ('M', 'B', 28, 0), Reward: 0
# State: ('M', 'B', 28, 36), Reward: 1
# State: ('M', 'B', 28, 38), Reward: 0
# State: ('M', 'B', 37, 12), Reward: 0
# State: ('M', 'B', 37, 23), Reward: 0
# State: ('M', 'B', 37, 14), Reward: 0
# State: ('M', 'B', 37, 15), Reward: 0
# State: ('M', 'B', 37, 9), Reward: 0
# State: ('M', 'B', 37, 21), Reward: 0
# State: ('M', 'B', 37, 11), Reward: 0
# State: ('M', 'B', 37, 25), Reward: 0
# State: ('M', 'B', 37, 8), Reward: 0
# State: ('M', 'B', 37, 27), Reward: 0
# State: ('M', 'B', 37, 18), Reward: 0
# State: ('M', 'B', 37, 32), Reward: 0
# State: ('M', 'B', 37, 5), Reward: 0
# State: ('M', 'B', 37, 20), Reward: 0
# State: ('M', 'B', 37, 10), Reward: 0
# State: ('M', 'B', 37, 13), Reward: 1
# State: ('M', 'B', 37, 24), Reward: 0
# State: ('M', 'B', 37, 7), Reward: 0
# State: ('M', 'B', 37, 22), Reward: 0
# State: ('M', 'B', 37, 17), Reward: 0
# State: ('M', 'B', 37, 28), Reward: 0
# State: ('M', 'B', 37, 6), Reward: 0
# State: ('M', 'B', 37, 19), Reward: 0
# State: ('M', 'B', 37, 26), Reward: 0
# State: ('M', 'B', 37, 16), Reward: 0
# State: ('M', 'B', 37, 30), Reward: 0
# State: ('M', 'B', 37, 4), Reward: 0
# State: ('M', 'B', 37, 2), Reward: 0
# State: ('M', 'B', 37, 31), Reward: 0
# State: ('M', 'B', 37, 3), Reward: 0
# State: ('M', 'B', 37, 29), Reward: 0
# State: ('M', 'B', 37, 33), Reward: 1
# State: ('M', 'B', 37, 34), Reward: 0
# State: ('M', 'B', 37, 1), Reward: 0
# State: ('M', 'B', 37, 35), Reward: 0
# State: ('M', 'B', 37, 0), Reward: 0
# State: ('M', 'B', 37, 36), Reward: 0
# State: ('M', 'B', 37, 38), Reward: 0
# State: ('M', 'B', 23, 12), Reward: 0
# State: ('M', 'B', 23, 23), Reward: 0
# State: ('M', 'B', 23, 14), Reward: 0
# State: ('M', 'B', 23, 15), Reward: 0
# State: ('M', 'B', 23, 9), Reward: 0
# State: ('M', 'B', 23, 21), Reward: 0
# State: ('M', 'B', 23, 11), Reward: 0
# State: ('M', 'B', 23, 25), Reward: 0
# State: ('M', 'B', 23, 8), Reward: 0
# State: ('M', 'B', 23, 27), Reward: 1
# State: ('M', 'B', 23, 18), Reward: 0
# State: ('M', 'B', 23, 32), Reward: 1
# State: ('M', 'B', 23, 5), Reward: 1
# State: ('M', 'B', 23, 20), Reward: 0
# State: ('M', 'B', 23, 10), Reward: 0
# State: ('M', 'B', 23, 13), Reward: 0
# State: ('M', 'B', 23, 24), Reward: 0
# State: ('M', 'B', 23, 7), Reward: 0
# State: ('M', 'B', 23, 22), Reward: 0
# State: ('M', 'B', 23, 17), Reward: 0
# State: ('M', 'B', 23, 28), Reward: 0
# State: ('M', 'B', 23, 6), Reward: 0
# State: ('M', 'B', 23, 19), Reward: 0
# State: ('M', 'B', 23, 26), Reward: 0
# State: ('M', 'B', 23, 16), Reward: 0
# State: ('M', 'B', 23, 30), Reward: 0
# State: ('M', 'B', 23, 4), Reward: 0
# State: ('M', 'B', 23, 2), Reward: 0
# State: ('M', 'B', 23, 31), Reward: 0
# State: ('M', 'B', 23, 3), Reward: 0
# State: ('M', 'B', 23, 29), Reward: 0
# State: ('M', 'B', 23, 33), Reward: 0
# State: ('M', 'B', 23, 34), Reward: 0
# State: ('M', 'B', 23, 1), Reward: 0
# State: ('M', 'B', 23, 35), Reward: 0
# State: ('M', 'B', 23, 0), Reward: 0
# State: ('M', 'B', 23, 36), Reward: 0
# State: ('M', 'B', 23, 38), Reward: 0
# State: ('M', 'B', 32, 12), Reward: 0
# State: ('M', 'B', 32, 23), Reward: 0
# State: ('M', 'B', 32, 14), Reward: 0
# State: ('M', 'B', 32, 15), Reward: 0
# State: ('M', 'B', 32, 9), Reward: 0
# State: ('M', 'B', 32, 21), Reward: 0
# State: ('M', 'B', 32, 11), Reward: 1
# State: ('M', 'B', 32, 25), Reward: 0
# State: ('M', 'B', 32, 8), Reward: 0
# State: ('M', 'B', 32, 27), Reward: 0
# State: ('M', 'B', 32, 18), Reward: 0
# State: ('M', 'B', 32, 32), Reward: 0
# State: ('M', 'B', 32, 5), Reward: 1
# State: ('M', 'B', 32, 20), Reward: 0
# State: ('M', 'B', 32, 10), Reward: 0
# State: ('M', 'B', 32, 13), Reward: 0
# State: ('M', 'B', 32, 24), Reward: 0
# State: ('M', 'B', 32, 7), Reward: 0
# State: ('M', 'B', 32, 22), Reward: 0
# State: ('M', 'B', 32, 17), Reward: 0
# State: ('M', 'B', 32, 28), Reward: 0
# State: ('M', 'B', 32, 6), Reward: 0
# State: ('M', 'B', 32, 19), Reward: 0
# State: ('M', 'B', 32, 26), Reward: 1
# State: ('M', 'B', 32, 16), Reward: 1
# State: ('M', 'B', 32, 30), Reward: 0
# State: ('M', 'B', 32, 4), Reward: 0
# State: ('M', 'B', 32, 2), Reward: 0
# State: ('M', 'B', 32, 31), Reward: 0
# State: ('M', 'B', 32, 3), Reward: 0
# State: ('M', 'B', 32, 29), Reward: 0
# State: ('M', 'B', 32, 33), Reward: 0
# State: ('M', 'B', 32, 34), Reward: 0
# State: ('M', 'B', 32, 1), Reward: 0
# State: ('M', 'B', 32, 35), Reward: 1
# State: ('M', 'B', 32, 0), Reward: 0
# State: ('M', 'B', 32, 36), Reward: 0
# State: ('M', 'B', 32, 38), Reward: 0
# State: ('M', 'B', 38, 12), Reward: 0
# State: ('M', 'B', 38, 23), Reward: 0
# State: ('M', 'B', 38, 14), Reward: 0
# State: ('M', 'B', 38, 15), Reward: 0
# State: ('M', 'B', 38, 9), Reward: 0
# State: ('M', 'B', 38, 21), Reward: 0
# State: ('M', 'B', 38, 11), Reward: 0
# State: ('M', 'B', 38, 25), Reward: 0
# State: ('M', 'B', 38, 8), Reward: 0
# State: ('M', 'B', 38, 27), Reward: 0
# State: ('M', 'B', 38, 18), Reward: 0
# State: ('M', 'B', 38, 32), Reward: 0
# State: ('M', 'B', 38, 5), Reward: 0
# State: ('M', 'B', 38, 20), Reward: 0
# State: ('M', 'B', 38, 10), Reward: 0
# State: ('M', 'B', 38, 13), Reward: 0
# State: ('M', 'B', 38, 24), Reward: 0
# State: ('M', 'B', 38, 7), Reward: 0
# State: ('M', 'B', 38, 22), Reward: 0
# State: ('M', 'B', 38, 17), Reward: 0
# State: ('M', 'B', 38, 28), Reward: 0
# State: ('M', 'B', 38, 6), Reward: 0
# State: ('M', 'B', 38, 19), Reward: 1
# State: ('M', 'B', 38, 26), Reward: 1
# State: ('M', 'B', 38, 16), Reward: 0
# State: ('M', 'B', 38, 30), Reward: 0
# State: ('M', 'B', 38, 4), Reward: 0
# State: ('M', 'B', 38, 2), Reward: 0
# State: ('M', 'B', 38, 31), Reward: 0
# State: ('M', 'B', 38, 3), Reward: 1
# State: ('M', 'B', 38, 29), Reward: 0
# State: ('M', 'B', 38, 33), Reward: 0
# State: ('M', 'B', 38, 34), Reward: 0
# State: ('M', 'B', 38, 1), Reward: 0
# State: ('M', 'B', 38, 35), Reward: 0
# State: ('M', 'B', 38, 0), Reward: 0
# State: ('M', 'B', 38, 36), Reward: 0
# State: ('M', 'B', 38, 38), Reward: 1
# State: ('M', 'B', 31, 12), Reward: 0
# State: ('M', 'B', 31, 23), Reward: 0
# State: ('M', 'B', 31, 14), Reward: 0
# State: ('M', 'B', 31, 15), Reward: 0
# State: ('M', 'B', 31, 9), Reward: 0
# State: ('M', 'B', 31, 21), Reward: 0
# State: ('M', 'B', 31, 11), Reward: 0
# State: ('M', 'B', 31, 25), Reward: 0
# State: ('M', 'B', 31, 8), Reward: 0
# State: ('M', 'B', 31, 27), Reward: 0
# State: ('M', 'B', 31, 18), Reward: 0
# State: ('M', 'B', 31, 32), Reward: 0
# State: ('M', 'B', 31, 5), Reward: 0
# State: ('M', 'B', 31, 20), Reward: 0
# State: ('M', 'B', 31, 10), Reward: 0
# State: ('M', 'B', 31, 13), Reward: 0
# State: ('M', 'B', 31, 24), Reward: 0
# State: ('M', 'B', 31, 7), Reward: 0
# State: ('M', 'B', 31, 22), Reward: 0
# State: ('M', 'B', 31, 17), Reward: 0
# State: ('M', 'B', 31, 28), Reward: 0
# State: ('M', 'B', 31, 6), Reward: 0
# State: ('M', 'B', 31, 19), Reward: 0
# State: ('M', 'B', 31, 26), Reward: 0
# State: ('M', 'B', 31, 16), Reward: 0
# State: ('M', 'B', 31, 30), Reward: 1
# State: ('M', 'B', 31, 4), Reward: 0
# State: ('M', 'B', 31, 2), Reward: 0
# State: ('M', 'B', 31, 31), Reward: 1
# State: ('M', 'B', 31, 3), Reward: 0
# State: ('M', 'B', 31, 29), Reward: 0
# State: ('M', 'B', 31, 33), Reward: 0
# State: ('M', 'B', 31, 34), Reward: 0
# State: ('M', 'B', 31, 1), Reward: 0
# State: ('M', 'B', 31, 35), Reward: 0
# State: ('M', 'B', 31, 0), Reward: 0
# State: ('M', 'B', 31, 36), Reward: 0
# State: ('M', 'B', 31, 38), Reward: 0
# State: ('M', 'B', 42, 12), Reward: 1
# State: ('M', 'B', 42, 23), Reward: 0
# State: ('M', 'B', 42, 14), Reward: 0
# State: ('M', 'B', 42, 15), Reward: 0
# State: ('M', 'B', 42, 9), Reward: 0
# State: ('M', 'B', 42, 21), Reward: 0
# State: ('M', 'B', 42, 11), Reward: 0
# State: ('M', 'B', 42, 25), Reward: 0
# State: ('M', 'B', 42, 8), Reward: 0
# State: ('M', 'B', 42, 27), Reward: 0
# State: ('M', 'B', 42, 18), Reward: 0
# State: ('M', 'B', 42, 32), Reward: 1
# State: ('M', 'B', 42, 5), Reward: 0
# State: ('M', 'B', 42, 20), Reward: 0
# State: ('M', 'B', 42, 10), Reward: 0
# State: ('M', 'B', 42, 13), Reward: 0
# State: ('M', 'B', 42, 24), Reward: 0
# State: ('M', 'B', 42, 7), Reward: 1
# State: ('M', 'B', 42, 22), Reward: 1
# State: ('M', 'B', 42, 17), Reward: 1
# State: ('M', 'B', 42, 28), Reward: 0
# State: ('M', 'B', 42, 6), Reward: 0
# State: ('M', 'B', 42, 19), Reward: 0
# State: ('M', 'B', 42, 26), Reward: 0
# State: ('M', 'B', 42, 16), Reward: 0
# State: ('M', 'B', 42, 30), Reward: 0
# State: ('M', 'B', 42, 4), Reward: 0
# State: ('M', 'B', 42, 2), Reward: 0
# State: ('M', 'B', 42, 31), Reward: 0
# State: ('M', 'B', 42, 3), Reward: 1
# State: ('M', 'B', 42, 29), Reward: 0
# State: ('M', 'B', 42, 33), Reward: 0
# State: ('M', 'B', 42, 34), Reward: 1
# State: ('M', 'B', 42, 1), Reward: 0
# State: ('M', 'B', 42, 35), Reward: 0
# State: ('M', 'B', 42, 0), Reward: 0
# State: ('M', 'B', 42, 36), Reward: 1
# State: ('M', 'B', 42, 38), Reward: 0
# State: ('M', 'B', 25, 12), Reward: 0
# State: ('M', 'B', 25, 23), Reward: 0
# State: ('M', 'B', 25, 14), Reward: 1
# State: ('M', 'B', 25, 15), Reward: 0
# State: ('M', 'B', 25, 9), Reward: 0
# State: ('M', 'B', 25, 21), Reward: 0
# State: ('M', 'B', 25, 11), Reward: 0
# State: ('M', 'B', 25, 25), Reward: 0
# State: ('M', 'B', 25, 8), Reward: 0
# State: ('M', 'B', 25, 27), Reward: 0
# State: ('M', 'B', 25, 18), Reward: 0
# State: ('M', 'B', 25, 32), Reward: 0
# State: ('M', 'B', 25, 5), Reward: 0
# State: ('M', 'B', 25, 20), Reward: 0
# State: ('M', 'B', 25, 10), Reward: 0
# State: ('M', 'B', 25, 13), Reward: 0
# State: ('M', 'B', 25, 24), Reward: 0
# State: ('M', 'B', 25, 7), Reward: 0
# State: ('M', 'B', 25, 22), Reward: 0
# State: ('M', 'B', 25, 17), Reward: 0
# State: ('M', 'B', 25, 28), Reward: 0
# State: ('M', 'B', 25, 6), Reward: 0
# State: ('M', 'B', 25, 19), Reward: 0
# State: ('M', 'B', 25, 26), Reward: 0
# State: ('M', 'B', 25, 16), Reward: 0
# State: ('M', 'B', 25, 30), Reward: 0
# State: ('M', 'B', 25, 4), Reward: 1
# State: ('M', 'B', 25, 2), Reward: 0
# State: ('M', 'B', 25, 31), Reward: 0
# State: ('M', 'B', 25, 3), Reward: 0
# State: ('M', 'B', 25, 29), Reward: 0
# State: ('M', 'B', 25, 33), Reward: 0
# State: ('M', 'B', 25, 34), Reward: 0
# State: ('M', 'B', 25, 1), Reward: 0
# State: ('M', 'B', 25, 35), Reward: 0
# State: ('M', 'B', 25, 0), Reward: 0
# State: ('M', 'B', 25, 36), Reward: 0
# State: ('M', 'B', 25, 38), Reward: 0
# State: ('M', 'B', 46, 12), Reward: 0
# State: ('M', 'B', 46, 23), Reward: 0
# State: ('M', 'B', 46, 14), Reward: 0
# State: ('M', 'B', 46, 15), Reward: 0
# State: ('M', 'B', 46, 9), Reward: 0
# State: ('M', 'B', 46, 21), Reward: 0
# State: ('M', 'B', 46, 11), Reward: 0
# State: ('M', 'B', 46, 25), Reward: 0
# State: ('M', 'B', 46, 8), Reward: 0
# State: ('M', 'B', 46, 27), Reward: 0
# State: ('M', 'B', 46, 18), Reward: 0
# State: ('M', 'B', 46, 32), Reward: 0
# State: ('M', 'B', 46, 5), Reward: 0
# State: ('M', 'B', 46, 20), Reward: 0
# State: ('M', 'B', 46, 10), Reward: 0
# State: ('M', 'B', 46, 13), Reward: 0
# State: ('M', 'B', 46, 24), Reward: 0
# State: ('M', 'B', 46, 7), Reward: 0
# State: ('M', 'B', 46, 22), Reward: 0
# State: ('M', 'B', 46, 17), Reward: 0
# State: ('M', 'B', 46, 28), Reward: 0
# State: ('M', 'B', 46, 6), Reward: 0
# State: ('M', 'B', 46, 19), Reward: 0
# State: ('M', 'B', 46, 26), Reward: 0
# State: ('M', 'B', 46, 16), Reward: 0
# State: ('M', 'B', 46, 30), Reward: 0
# State: ('M', 'B', 46, 4), Reward: 0
# State: ('M', 'B', 46, 2), Reward: 0
# State: ('M', 'B', 46, 31), Reward: 0
# State: ('M', 'B', 46, 3), Reward: 0
# State: ('M', 'B', 46, 29), Reward: 0
# State: ('M', 'B', 46, 33), Reward: 0
# State: ('M', 'B', 46, 34), Reward: 0
# State: ('M', 'B', 46, 1), Reward: 0
# State: ('M', 'B', 46, 35), Reward: 0
# State: ('M', 'B', 46, 0), Reward: 0
# State: ('M', 'B', 46, 36), Reward: 0
# State: ('M', 'B', 46, 38), Reward: 0
# State: ('M', 'B', 45, 12), Reward: 0
# State: ('M', 'B', 45, 23), Reward: 0
# State: ('M', 'B', 45, 14), Reward: 0
# State: ('M', 'B', 45, 15), Reward: 0
# State: ('M', 'B', 45, 9), Reward: 0
# State: ('M', 'B', 45, 21), Reward: 0
# State: ('M', 'B', 45, 11), Reward: 0
# State: ('M', 'B', 45, 25), Reward: 0
# State: ('M', 'B', 45, 8), Reward: 0
# State: ('M', 'B', 45, 27), Reward: 0
# State: ('M', 'B', 45, 18), Reward: 0
# State: ('M', 'B', 45, 32), Reward: 0
# State: ('M', 'B', 45, 5), Reward: 0
# State: ('M', 'B', 45, 20), Reward: 0
# State: ('M', 'B', 45, 10), Reward: 0
# State: ('M', 'B', 45, 13), Reward: 0
# State: ('M', 'B', 45, 24), Reward: 0
# State: ('M', 'B', 45, 7), Reward: 0
# State: ('M', 'B', 45, 22), Reward: 0
# State: ('M', 'B', 45, 17), Reward: 1
# State: ('M', 'B', 45, 28), Reward: 0
# State: ('M', 'B', 45, 6), Reward: 0
# State: ('M', 'B', 45, 19), Reward: 0
# State: ('M', 'B', 45, 26), Reward: 0
# State: ('M', 'B', 45, 16), Reward: 0
# State: ('M', 'B', 45, 30), Reward: 0
# State: ('M', 'B', 45, 4), Reward: 1
# State: ('M', 'B', 45, 2), Reward: 0
# State: ('M', 'B', 45, 31), Reward: 0
# State: ('M', 'B', 45, 3), Reward: 0
# State: ('M', 'B', 45, 29), Reward: 0
# State: ('M', 'B', 45, 33), Reward: 0
# State: ('M', 'B', 45, 34), Reward: 0
# State: ('M', 'B', 45, 1), Reward: 0
# State: ('M', 'B', 45, 35), Reward: 0
# State: ('M', 'B', 45, 0), Reward: 0
# State: ('M', 'B', 45, 36), Reward: 0
# State: ('M', 'B', 45, 38), Reward: 0
# State: ('M', 'B', 21, 12), Reward: 0
# State: ('M', 'B', 21, 23), Reward: 0
# State: ('M', 'B', 21, 14), Reward: 0
# State: ('M', 'B', 21, 15), Reward: 0
# State: ('M', 'B', 21, 9), Reward: 1
# State: ('M', 'B', 21, 21), Reward: 0
# State: ('M', 'B', 21, 11), Reward: 0
# State: ('M', 'B', 21, 25), Reward: 0
# State: ('M', 'B', 21, 8), Reward: 0
# State: ('M', 'B', 21, 27), Reward: 0
# State: ('M', 'B', 21, 18), Reward: 0
# State: ('M', 'B', 21, 32), Reward: 0
# State: ('M', 'B', 21, 5), Reward: 0
# State: ('M', 'B', 21, 20), Reward: 0
# State: ('M', 'B', 21, 10), Reward: 1
# State: ('M', 'B', 21, 13), Reward: 0
# State: ('M', 'B', 21, 24), Reward: 0
# State: ('M', 'B', 21, 7), Reward: 0
# State: ('M', 'B', 21, 22), Reward: 0
# State: ('M', 'B', 21, 17), Reward: 0
# State: ('M', 'B', 21, 28), Reward: 0
# State: ('M', 'B', 21, 6), Reward: 0
# State: ('M', 'B', 21, 19), Reward: 0
# State: ('M', 'B', 21, 26), Reward: 0
# State: ('M', 'B', 21, 16), Reward: 0
# State: ('M', 'B', 21, 30), Reward: 0
# State: ('M', 'B', 21, 4), Reward: 0
# State: ('M', 'B', 21, 2), Reward: 0
# State: ('M', 'B', 21, 31), Reward: 0
# State: ('M', 'B', 21, 3), Reward: 0
# State: ('M', 'B', 21, 29), Reward: 0
# State: ('M', 'B', 21, 33), Reward: 0
# State: ('M', 'B', 21, 34), Reward: 0
# State: ('M', 'B', 21, 1), Reward: 0
# State: ('M', 'B', 21, 35), Reward: 0
# State: ('M', 'B', 21, 0), Reward: 0
# State: ('M', 'B', 21, 36), Reward: 0
# State: ('M', 'B', 21, 38), Reward: 0
# State: ('M', 'B', 20, 12), Reward: 0
# State: ('M', 'B', 20, 23), Reward: 0
# State: ('M', 'B', 20, 14), Reward: 0
# State: ('M', 'B', 20, 15), Reward: 0
# State: ('M', 'B', 20, 9), Reward: 0
# State: ('M', 'B', 20, 21), Reward: 1
# State: ('M', 'B', 20, 11), Reward: 0
# State: ('M', 'B', 20, 25), Reward: 0
# State: ('M', 'B', 20, 8), Reward: 0
# State: ('M', 'B', 20, 27), Reward: 0
# State: ('M', 'B', 20, 18), Reward: 0
# State: ('M', 'B', 20, 32), Reward: 0
# State: ('M', 'B', 20, 5), Reward: 0
# State: ('M', 'B', 20, 20), Reward: 0
# State: ('M', 'B', 20, 10), Reward: 0
# State: ('M', 'B', 20, 13), Reward: 0
# State: ('M', 'B', 20, 24), Reward: 1
# State: ('M', 'B', 20, 7), Reward: 0
# State: ('M', 'B', 20, 22), Reward: 1
# State: ('M', 'B', 20, 17), Reward: 1
# State: ('M', 'B', 20, 28), Reward: 0
# State: ('M', 'B', 20, 6), Reward: 0
# State: ('M', 'B', 20, 19), Reward: 0
# State: ('M', 'B', 20, 26), Reward: 0
# State: ('M', 'B', 20, 16), Reward: 0
# State: ('M', 'B', 20, 30), Reward: 0
# State: ('M', 'B', 20, 4), Reward: 0
# State: ('M', 'B', 20, 2), Reward: 0
# State: ('M', 'B', 20, 31), Reward: 0
# State: ('M', 'B', 20, 3), Reward: 0
# State: ('M', 'B', 20, 29), Reward: 0
# State: ('M', 'B', 20, 33), Reward: 0
# State: ('M', 'B', 20, 34), Reward: 0
# State: ('M', 'B', 20, 1), Reward: 1
# State: ('M', 'B', 20, 35), Reward: 0
# State: ('M', 'B', 20, 0), Reward: 0
# State: ('M', 'B', 20, 36), Reward: 0
# State: ('M', 'B', 20, 38), Reward: 0
# State: ('M', 'B', 50, 12), Reward: 0
# State: ('M', 'B', 50, 23), Reward: 0
# State: ('M', 'B', 50, 14), Reward: 0
# State: ('M', 'B', 50, 15), Reward: 0
# State: ('M', 'B', 50, 9), Reward: 0
# State: ('M', 'B', 50, 21), Reward: 0
# State: ('M', 'B', 50, 11), Reward: 0
# State: ('M', 'B', 50, 25), Reward: 0
# State: ('M', 'B', 50, 8), Reward: 1
# State: ('M', 'B', 50, 27), Reward: 0
# State: ('M', 'B', 50, 18), Reward: 0
# State: ('M', 'B', 50, 32), Reward: 0
# State: ('M', 'B', 50, 5), Reward: 0
# State: ('M', 'B', 50, 20), Reward: 0
# State: ('M', 'B', 50, 10), Reward: 0
# State: ('M', 'B', 50, 13), Reward: 1
# State: ('M', 'B', 50, 24), Reward: 0
# State: ('M', 'B', 50, 7), Reward: 0
# State: ('M', 'B', 50, 22), Reward: 0
# State: ('M', 'B', 50, 17), Reward: 0
# State: ('M', 'B', 50, 28), Reward: 0
# State: ('M', 'B', 50, 6), Reward: 0
# State: ('M', 'B', 50, 19), Reward: 0
# State: ('M', 'B', 50, 26), Reward: 0
# State: ('M', 'B', 50, 16), Reward: 0
# State: ('M', 'B', 50, 30), Reward: 0
# State: ('M', 'B', 50, 4), Reward: 0
# State: ('M', 'B', 50, 2), Reward: 0
# State: ('M', 'B', 50, 31), Reward: 0
# State: ('M', 'B', 50, 3), Reward: 0
# State: ('M', 'B', 50, 29), Reward: 0
# State: ('M', 'B', 50, 33), Reward: 0
# State: ('M', 'B', 50, 34), Reward: 0
# State: ('M', 'B', 50, 1), Reward: 0
# State: ('M', 'B', 50, 35), Reward: 1
# State: ('M', 'B', 50, 0), Reward: 0
# State: ('M', 'B', 50, 36), Reward: 0
# State: ('M', 'B', 50, 38), Reward: 0
# State: ('M', 'B', 18, 12), Reward: 0
# State: ('M', 'B', 18, 23), Reward: 0
# State: ('M', 'B', 18, 14), Reward: 0
# State: ('M', 'B', 18, 15), Reward: 0
# State: ('M', 'B', 18, 9), Reward: 0
# State: ('M', 'B', 18, 21), Reward: 0
# State: ('M', 'B', 18, 11), Reward: 0
# State: ('M', 'B', 18, 25), Reward: 0
# State: ('M', 'B', 18, 8), Reward: 0
# State: ('M', 'B', 18, 27), Reward: 0
# State: ('M', 'B', 18, 18), Reward: 0
# State: ('M', 'B', 18, 32), Reward: 1
# State: ('M', 'B', 18, 5), Reward: 0
# State: ('M', 'B', 18, 20), Reward: 0
# State: ('M', 'B', 18, 10), Reward: 0
# State: ('M', 'B', 18, 13), Reward: 0
# State: ('M', 'B', 18, 24), Reward: 0
# State: ('M', 'B', 18, 7), Reward: 0
# State: ('M', 'B', 18, 22), Reward: 0
# State: ('M', 'B', 18, 17), Reward: 0
# State: ('M', 'B', 18, 28), Reward: 0
# State: ('M', 'B', 18, 6), Reward: 0
# State: ('M', 'B', 18, 19), Reward: 1
# State: ('M', 'B', 18, 26), Reward: 0
# State: ('M', 'B', 18, 16), Reward: 0
# State: ('M', 'B', 18, 30), Reward: 0
# State: ('M', 'B', 18, 4), Reward: 0
# State: ('M', 'B', 18, 2), Reward: 0
# State: ('M', 'B', 18, 31), Reward: 0
# State: ('M', 'B', 18, 3), Reward: 0
# State: ('M', 'B', 18, 29), Reward: 0
# State: ('M', 'B', 18, 33), Reward: 1
# State: ('M', 'B', 18, 34), Reward: 0
# State: ('M', 'B', 18, 1), Reward: 0
# State: ('M', 'B', 18, 35), Reward: 0
# State: ('M', 'B', 18, 0), Reward: 0
# State: ('M', 'B', 18, 36), Reward: 0
# State: ('M', 'B', 18, 38), Reward: 0
# State: ('M', 'B', 43, 12), Reward: 1
# State: ('M', 'B', 43, 23), Reward: 0
# State: ('M', 'B', 43, 14), Reward: 0
# State: ('M', 'B', 43, 15), Reward: 0
# State: ('M', 'B', 43, 9), Reward: 0
# State: ('M', 'B', 43, 21), Reward: 0
# State: ('M', 'B', 43, 11), Reward: 0
# State: ('M', 'B', 43, 25), Reward: 0
# State: ('M', 'B', 43, 8), Reward: 0
# State: ('M', 'B', 43, 27), Reward: 0
# State: ('M', 'B', 43, 18), Reward: 0
# State: ('M', 'B', 43, 32), Reward: 0
# State: ('M', 'B', 43, 5), Reward: 0
# State: ('M', 'B', 43, 20), Reward: 0
# State: ('M', 'B', 43, 10), Reward: 0
# State: ('M', 'B', 43, 13), Reward: 0
# State: ('M', 'B', 43, 24), Reward: 1
# State: ('M', 'B', 43, 7), Reward: 0
# State: ('M', 'B', 43, 22), Reward: 0
# State: ('M', 'B', 43, 17), Reward: 0
# State: ('M', 'B', 43, 28), Reward: 0
# State: ('M', 'B', 43, 6), Reward: 0
# State: ('M', 'B', 43, 19), Reward: 0
# State: ('M', 'B', 43, 26), Reward: 0
# State: ('M', 'B', 43, 16), Reward: 0
# State: ('M', 'B', 43, 30), Reward: 0
# State: ('M', 'B', 43, 4), Reward: 0
# State: ('M', 'B', 43, 2), Reward: 0
# State: ('M', 'B', 43, 31), Reward: 0
# State: ('M', 'B', 43, 3), Reward: 0
# State: ('M', 'B', 43, 29), Reward: 0
# State: ('M', 'B', 43, 33), Reward: 0
# State: ('M', 'B', 43, 34), Reward: 0
# State: ('M', 'B', 43, 1), Reward: 0
# State: ('M', 'B', 43, 35), Reward: 0
# State: ('M', 'B', 43, 0), Reward: 0
# State: ('M', 'B', 43, 36), Reward: 0
# State: ('M', 'B', 43, 38), Reward: 0
# State: ('M', 'B', 19, 12), Reward: 1
# State: ('M', 'B', 19, 23), Reward: 0
# State: ('M', 'B', 19, 14), Reward: 0
# State: ('M', 'B', 19, 15), Reward: 0
# State: ('M', 'B', 19, 9), Reward: 0
# State: ('M', 'B', 19, 21), Reward: 0
# State: ('M', 'B', 19, 11), Reward: 0
# State: ('M', 'B', 19, 25), Reward: 0
# State: ('M', 'B', 19, 8), Reward: 0
# State: ('M', 'B', 19, 27), Reward: 0
# State: ('M', 'B', 19, 18), Reward: 0
# State: ('M', 'B', 19, 32), Reward: 0
# State: ('M', 'B', 19, 5), Reward: 0
# State: ('M', 'B', 19, 20), Reward: 0
# State: ('M', 'B', 19, 10), Reward: 0
# State: ('M', 'B', 19, 13), Reward: 0
# State: ('M', 'B', 19, 24), Reward: 0
# State: ('M', 'B', 19, 7), Reward: 1
# State: ('M', 'B', 19, 22), Reward: 0
# State: ('M', 'B', 19, 17), Reward: 0
# State: ('M', 'B', 19, 28), Reward: 0
# State: ('M', 'B', 19, 6), Reward: 1
# State: ('M', 'B', 19, 19), Reward: 1
# State: ('M', 'B', 19, 26), Reward: 0
# State: ('M', 'B', 19, 16), Reward: 1
# State: ('M', 'B', 19, 30), Reward: 0
# State: ('M', 'B', 19, 4), Reward: 0
# State: ('M', 'B', 19, 2), Reward: 0
# State: ('M', 'B', 19, 31), Reward: 0
# State: ('M', 'B', 19, 3), Reward: 0
# State: ('M', 'B', 19, 29), Reward: 0
# State: ('M', 'B', 19, 33), Reward: 0
# State: ('M', 'B', 19, 34), Reward: 0
# State: ('M', 'B', 19, 1), Reward: 0
# State: ('M', 'B', 19, 35), Reward: 0
# State: ('M', 'B', 19, 0), Reward: 0
# State: ('M', 'B', 19, 36), Reward: 0
# State: ('M', 'B', 19, 38), Reward: 0
# State: ('M', 'B', 24, 12), Reward: 0
# State: ('M', 'B', 24, 23), Reward: 0
# State: ('M', 'B', 24, 14), Reward: 0
# State: ('M', 'B', 24, 15), Reward: 0
# State: ('M', 'B', 24, 9), Reward: 0
# State: ('M', 'B', 24, 21), Reward: 0
# State: ('M', 'B', 24, 11), Reward: 0
# State: ('M', 'B', 24, 25), Reward: 0
# State: ('M', 'B', 24, 8), Reward: 0
# State: ('M', 'B', 24, 27), Reward: 0
# State: ('M', 'B', 24, 18), Reward: 0
# State: ('M', 'B', 24, 32), Reward: 0
# State: ('M', 'B', 24, 5), Reward: 0
# State: ('M', 'B', 24, 20), Reward: 0
# State: ('M', 'B', 24, 10), Reward: 0
# State: ('M', 'B', 24, 13), Reward: 0
# State: ('M', 'B', 24, 24), Reward: 1
# State: ('M', 'B', 24, 7), Reward: 0
# State: ('M', 'B', 24, 22), Reward: 0
# State: ('M', 'B', 24, 17), Reward: 0
# State: ('M', 'B', 24, 28), Reward: 0
# State: ('M', 'B', 24, 6), Reward: 0
# State: ('M', 'B', 24, 19), Reward: 0
# State: ('M', 'B', 24, 26), Reward: 1
# State: ('M', 'B', 24, 16), Reward: 0
# State: ('M', 'B', 24, 30), Reward: 0
# State: ('M', 'B', 24, 4), Reward: 0
# State: ('M', 'B', 24, 2), Reward: 0
# State: ('M', 'B', 24, 31), Reward: 0
# State: ('M', 'B', 24, 3), Reward: 0
# State: ('M', 'B', 24, 29), Reward: 0
# State: ('M', 'B', 24, 33), Reward: 0
# State: ('M', 'B', 24, 34), Reward: 0
# State: ('M', 'B', 24, 1), Reward: 0
# State: ('M', 'B', 24, 35), Reward: 0
# State: ('M', 'B', 24, 0), Reward: 0
# State: ('M', 'B', 24, 36), Reward: 0
# State: ('M', 'B', 24, 38), Reward: 1
# State: ('M', 'B', 22, 12), Reward: 0
# State: ('M', 'B', 22, 23), Reward: 0
# State: ('M', 'B', 22, 14), Reward: 0
# State: ('M', 'B', 22, 15), Reward: 0
# State: ('M', 'B', 22, 9), Reward: 0
# State: ('M', 'B', 22, 21), Reward: 0
# State: ('M', 'B', 22, 11), Reward: 0
# State: ('M', 'B', 22, 25), Reward: 0
# State: ('M', 'B', 22, 8), Reward: 0
# State: ('M', 'B', 22, 27), Reward: 0
# State: ('M', 'B', 22, 18), Reward: 0
# State: ('M', 'B', 22, 32), Reward: 0
# State: ('M', 'B', 22, 5), Reward: 1
# State: ('M', 'B', 22, 20), Reward: 0
# State: ('M', 'B', 22, 10), Reward: 0
# State: ('M', 'B', 22, 13), Reward: 0
# State: ('M', 'B', 22, 24), Reward: 0
# State: ('M', 'B', 22, 7), Reward: 1
# State: ('M', 'B', 22, 22), Reward: 0
# State: ('M', 'B', 22, 17), Reward: 0
# State: ('M', 'B', 22, 28), Reward: 0
# State: ('M', 'B', 22, 6), Reward: 0
# State: ('M', 'B', 22, 19), Reward: 0
# State: ('M', 'B', 22, 26), Reward: 0
# State: ('M', 'B', 22, 16), Reward: 0
# State: ('M', 'B', 22, 30), Reward: 0
# State: ('M', 'B', 22, 4), Reward: 0
# State: ('M', 'B', 22, 2), Reward: 0
# State: ('M', 'B', 22, 31), Reward: 0
# State: ('M', 'B', 22, 3), Reward: 0
# State: ('M', 'B', 22, 29), Reward: 0
# State: ('M', 'B', 22, 33), Reward: 0
# State: ('M', 'B', 22, 34), Reward: 0
# State: ('M', 'B', 22, 1), Reward: 0
# State: ('M', 'B', 22, 35), Reward: 0
# State: ('M', 'B', 22, 0), Reward: 0
# State: ('M', 'B', 22, 36), Reward: 0
# State: ('M', 'B', 22, 38), Reward: 0
# State: ('M', 'B', 48, 12), Reward: 0
# State: ('M', 'B', 48, 23), Reward: 0
# State: ('M', 'B', 48, 14), Reward: 0
# State: ('M', 'B', 48, 15), Reward: 0
# State: ('M', 'B', 48, 9), Reward: 0
# State: ('M', 'B', 48, 21), Reward: 0
# State: ('M', 'B', 48, 11), Reward: 0
# State: ('M', 'B', 48, 25), Reward: 0
# State: ('M', 'B', 48, 8), Reward: 1
# State: ('M', 'B', 48, 27), Reward: 0
# State: ('M', 'B', 48, 18), Reward: 0
# State: ('M', 'B', 48, 32), Reward: 0
# State: ('M', 'B', 48, 5), Reward: 0
# State: ('M', 'B', 48, 20), Reward: 1
# State: ('M', 'B', 48, 10), Reward: 0
# State: ('M', 'B', 48, 13), Reward: 0
# State: ('M', 'B', 48, 24), Reward: 0
# State: ('M', 'B', 48, 7), Reward: 0
# State: ('M', 'B', 48, 22), Reward: 0
# State: ('M', 'B', 48, 17), Reward: 0
# State: ('M', 'B', 48, 28), Reward: 0
# State: ('M', 'B', 48, 6), Reward: 0
# State: ('M', 'B', 48, 19), Reward: 0
# State: ('M', 'B', 48, 26), Reward: 1
# State: ('M', 'B', 48, 16), Reward: 0
# State: ('M', 'B', 48, 30), Reward: 0
# State: ('M', 'B', 48, 4), Reward: 0
# State: ('M', 'B', 48, 2), Reward: 0
# State: ('M', 'B', 48, 31), Reward: 1
# State: ('M', 'B', 48, 3), Reward: 0
# State: ('M', 'B', 48, 29), Reward: 0
# State: ('M', 'B', 48, 33), Reward: 0
# State: ('M', 'B', 48, 34), Reward: 0
# State: ('M', 'B', 48, 1), Reward: 1
# State: ('M', 'B', 48, 35), Reward: 0
# State: ('M', 'B', 48, 0), Reward: 0
# State: ('M', 'B', 48, 36), Reward: 0
# State: ('M', 'B', 48, 38), Reward: 0
# State: ('M', 'B', 53, 12), Reward: 0
# State: ('M', 'B', 53, 23), Reward: 0
# State: ('M', 'B', 53, 14), Reward: 1
# State: ('M', 'B', 53, 15), Reward: 1
# State: ('M', 'B', 53, 9), Reward: 0
# State: ('M', 'B', 53, 21), Reward: 0
# State: ('M', 'B', 53, 11), Reward: 0
# State: ('M', 'B', 53, 25), Reward: 0
# State: ('M', 'B', 53, 8), Reward: 0
# State: ('M', 'B', 53, 27), Reward: 0
# State: ('M', 'B', 53, 18), Reward: 0
# State: ('M', 'B', 53, 32), Reward: 0
# State: ('M', 'B', 53, 5), Reward: 1
# State: ('M', 'B', 53, 20), Reward: 0
# State: ('M', 'B', 53, 10), Reward: 0
# State: ('M', 'B', 53, 13), Reward: 0
# State: ('M', 'B', 53, 24), Reward: 0
# State: ('M', 'B', 53, 7), Reward: 0
# State: ('M', 'B', 53, 22), Reward: 0
# State: ('M', 'B', 53, 17), Reward: 0
# State: ('M', 'B', 53, 28), Reward: 0
# State: ('M', 'B', 53, 6), Reward: 0
# State: ('M', 'B', 53, 19), Reward: 0
# State: ('M', 'B', 53, 26), Reward: 0
# State: ('M', 'B', 53, 16), Reward: 1
# State: ('M', 'B', 53, 30), Reward: 0
# State: ('M', 'B', 53, 4), Reward: 0
# State: ('M', 'B', 53, 2), Reward: 0
# State: ('M', 'B', 53, 31), Reward: 0
# State: ('M', 'B', 53, 3), Reward: 0
# State: ('M', 'B', 53, 29), Reward: 0
# State: ('M', 'B', 53, 33), Reward: 1
# State: ('M', 'B', 53, 34), Reward: 0
# State: ('M', 'B', 53, 1), Reward: 0
# State: ('M', 'B', 53, 35), Reward: 0
# State: ('M', 'B', 53, 0), Reward: 0
# State: ('M', 'B', 53, 36), Reward: 0
# State: ('M', 'B', 53, 38), Reward: 0
# State: ('M', 'B', 49, 12), Reward: 0
# State: ('M', 'B', 49, 23), Reward: 0
# State: ('M', 'B', 49, 14), Reward: 0
# State: ('M', 'B', 49, 15), Reward: 0
# State: ('M', 'B', 49, 9), Reward: 1
# State: ('M', 'B', 49, 21), Reward: 1
# State: ('M', 'B', 49, 11), Reward: 0
# State: ('M', 'B', 49, 25), Reward: 0
# State: ('M', 'B', 49, 8), Reward: 1
# State: ('M', 'B', 49, 27), Reward: 0
# State: ('M', 'B', 49, 18), Reward: 0
# State: ('M', 'B', 49, 32), Reward: 0
# State: ('M', 'B', 49, 5), Reward: 0
# State: ('M', 'B', 49, 20), Reward: 0
# State: ('M', 'B', 49, 10), Reward: 0
# State: ('M', 'B', 49, 13), Reward: 0
# State: ('M', 'B', 49, 24), Reward: 0
# State: ('M', 'B', 49, 7), Reward: 0
# State: ('M', 'B', 49, 22), Reward: 0
# State: ('M', 'B', 49, 17), Reward: 0
# State: ('M', 'B', 49, 28), Reward: 0
# State: ('M', 'B', 49, 6), Reward: 0
# State: ('M', 'B', 49, 19), Reward: 0
# State: ('M', 'B', 49, 26), Reward: 0
# State: ('M', 'B', 49, 16), Reward: 0
# State: ('M', 'B', 49, 30), Reward: 0
# State: ('M', 'B', 49, 4), Reward: 0
# State: ('M', 'B', 49, 2), Reward: 0
# State: ('M', 'B', 49, 31), Reward: 0
# State: ('M', 'B', 49, 3), Reward: 0
# State: ('M', 'B', 49, 29), Reward: 0
# State: ('M', 'B', 49, 33), Reward: 0
# State: ('M', 'B', 49, 34), Reward: 0
# State: ('M', 'B', 49, 1), Reward: 1
# State: ('M', 'B', 49, 35), Reward: 0
# State: ('M', 'B', 49, 0), Reward: 0
# State: ('M', 'B', 49, 36), Reward: 0
# State: ('M', 'B', 49, 38), Reward: 0
# State: ('M', 'B', 47, 12), Reward: 1
# State: ('M', 'B', 47, 23), Reward: 0
# State: ('M', 'B', 47, 14), Reward: 0
# State: ('M', 'B', 47, 15), Reward: 0
# State: ('M', 'B', 47, 9), Reward: 0
# State: ('M', 'B', 47, 21), Reward: 0
# State: ('M', 'B', 47, 11), Reward: 0
# State: ('M', 'B', 47, 25), Reward: 0
# State: ('M', 'B', 47, 8), Reward: 0
# State: ('M', 'B', 47, 27), Reward: 0
# State: ('M', 'B', 47, 18), Reward: 0
# State: ('M', 'B', 47, 32), Reward: 0
# State: ('M', 'B', 47, 5), Reward: 1
# State: ('M', 'B', 47, 20), Reward: 0
# State: ('M', 'B', 47, 10), Reward: 0
# State: ('M', 'B', 47, 13), Reward: 0
# State: ('M', 'B', 47, 24), Reward: 0
# State: ('M', 'B', 47, 7), Reward: 0
# State: ('M', 'B', 47, 22), Reward: 0
# State: ('M', 'B', 47, 17), Reward: 0
# State: ('M', 'B', 47, 28), Reward: 0
# State: ('M', 'B', 47, 6), Reward: 0
# State: ('M', 'B', 47, 19), Reward: 0
# State: ('M', 'B', 47, 26), Reward: 0
# State: ('M', 'B', 47, 16), Reward: 0
# State: ('M', 'B', 47, 30), Reward: 0
# State: ('M', 'B', 47, 4), Reward: 0
# State: ('M', 'B', 47, 2), Reward: 0
# State: ('M', 'B', 47, 31), Reward: 0
# State: ('M', 'B', 47, 3), Reward: 1
# State: ('M', 'B', 47, 29), Reward: 1
# State: ('M', 'B', 47, 33), Reward: 0
# State: ('M', 'B', 47, 34), Reward: 0
# State: ('M', 'B', 47, 1), Reward: 0
# State: ('M', 'B', 47, 35), Reward: 1
# State: ('M', 'B', 47, 0), Reward: 0
# State: ('M', 'B', 47, 36), Reward: 0
# State: ('M', 'B', 47, 38), Reward: 0
# State: ('M', 'B', 51, 12), Reward: 0
# State: ('M', 'B', 51, 23), Reward: 0
# State: ('M', 'B', 51, 14), Reward: 0
# State: ('M', 'B', 51, 15), Reward: 0
# State: ('M', 'B', 51, 9), Reward: 0
# State: ('M', 'B', 51, 21), Reward: 0
# State: ('M', 'B', 51, 11), Reward: 0
# State: ('M', 'B', 51, 25), Reward: 1
# State: ('M', 'B', 51, 8), Reward: 0
# State: ('M', 'B', 51, 27), Reward: 0
# State: ('M', 'B', 51, 18), Reward: 0
# State: ('M', 'B', 51, 32), Reward: 0
# State: ('M', 'B', 51, 5), Reward: 0
# State: ('M', 'B', 51, 20), Reward: 0
# ...
# State: ('F', 'C', 51, 6), Reward: 1
# State: ('F', 'C', 51, 19), Reward: 0
# State: ('F', 'C', 51, 26), Reward: 0
# State: ('F', 'C', 51, 16), Reward: 0
# State: ('F', 'C', 51, 30), Reward: 0
# State: ('F', 'C', 51, 4), Reward: 0
# State: ('F', 'C', 51, 2), Reward: 0
# State: ('F', 'C', 51, 31), Reward: 0
# State: ('F', 'C', 51, 3), Reward: 0
# State: ('F', 'C', 51, 29), Reward: 0
# State: ('F', 'C', 51, 33), Reward: 0
# State: ('F', 'C', 51, 34), Reward: 0
# State: ('F', 'C', 51, 1), Reward: 0
# State: ('F', 'C', 51, 35), Reward: 0
# State: ('F', 'C', 51, 0), Reward: 0
# State: ('F', 'C', 51, 36), Reward: 0
# State: ('F', 'C', 51, 38), Reward: 0
# State: ('F', 'C', 52, 12), Reward: 0
# State: ('F', 'C', 52, 23), Reward: 0
# State: ('F', 'C', 52, 14), Reward: 0
# State: ('F', 'C', 52, 15), Reward: 0
# State: ('F', 'C', 52, 9), Reward: 0
# State: ('F', 'C', 52, 21), Reward: 0
# State: ('F', 'C', 52, 11), Reward: 0
# State: ('F', 'C', 52, 25), Reward: 0
# State: ('F', 'C', 52, 8), Reward: 0
# State: ('F', 'C', 52, 27), Reward: 0
# State: ('F', 'C', 52, 18), Reward: 0
# State: ('F', 'C', 52, 32), Reward: 0
# State: ('F', 'C', 52, 5), Reward: 0
# State: ('F', 'C', 52, 20), Reward: 0
# State: ('F', 'C', 52, 10), Reward: 0
# State: ('F', 'C', 52, 13), Reward: 0
# State: ('F', 'C', 52, 24), Reward: 0
# State: ('F', 'C', 52, 7), Reward: 0
# State: ('F', 'C', 52, 22), Reward: 1
# State: ('F', 'C', 52, 17), Reward: 0
# State: ('F', 'C', 52, 28), Reward: 1
# State: ('F', 'C', 52, 6), Reward: 1
# State: ('F', 'C', 52, 19), Reward: 0
# State: ('F', 'C', 52, 26), Reward: 0
# State: ('F', 'C', 52, 16), Reward: 0
# State: ('F', 'C', 52, 30), Reward: 0
# State: ('F', 'C', 52, 4), Reward: 0
# State: ('F', 'C', 52, 2), Reward: 1
# State: ('F', 'C', 52, 31), Reward: 0
# State: ('F', 'C', 52, 3), Reward: 0
# State: ('F', 'C', 52, 29), Reward: 0
# State: ('F', 'C', 52, 33), Reward: 0
# State: ('F', 'C', 52, 34), Reward: 0
# State: ('F', 'C', 52, 1), Reward: 0
# State: ('F', 'C', 52, 35), Reward: 0
# State: ('F', 'C', 52, 0), Reward: 0
# State: ('F', 'C', 52, 36), Reward: 0
# State: ('F', 'C', 52, 38), Reward: 0
# State: ('F', 'C', 54, 12), Reward: 0
# State: ('F', 'C', 54, 23), Reward: 0
# State: ('F', 'C', 54, 14), Reward: 0
# State: ('F', 'C', 54, 15), Reward: 0
# State: ('F', 'C', 54, 9), Reward: 0
# State: ('F', 'C', 54, 21), Reward: 0
# State: ('F', 'C', 54, 11), Reward: 0
# State: ('F', 'C', 54, 25), Reward: 0
# State: ('F', 'C', 54, 8), Reward: 0
# State: ('F', 'C', 54, 27), Reward: 0
# State: ('F', 'C', 54, 18), Reward: 0
# State: ('F', 'C', 54, 32), Reward: 0
# State: ('F', 'C', 54, 5), Reward: 0
# State: ('F', 'C', 54, 20), Reward: 0
# State: ('F', 'C', 54, 10), Reward: 0
# State: ('F', 'C', 54, 13), Reward: 0
# State: ('F', 'C', 54, 24), Reward: 0
# State: ('F', 'C', 54, 7), Reward: 0
# State: ('F', 'C', 54, 22), Reward: 0
# State: ('F', 'C', 54, 17), Reward: 0
# State: ('F', 'C', 54, 28), Reward: 0
# State: ('F', 'C', 54, 6), Reward: 0
# State: ('F', 'C', 54, 19), Reward: 0
# State: ('F', 'C', 54, 26), Reward: 0
# State: ('F', 'C', 54, 16), Reward: 0
# State: ('F', 'C', 54, 30), Reward: 0
# State: ('F', 'C', 54, 4), Reward: 0
# State: ('F', 'C', 54, 2), Reward: 0
# State: ('F', 'C', 54, 31), Reward: 0
# State: ('F', 'C', 54, 3), Reward: 0
# State: ('F', 'C', 54, 29), Reward: 0
# State: ('F', 'C', 54, 33), Reward: 0
# State: ('F', 'C', 54, 34), Reward: 0
# State: ('F', 'C', 54, 1), Reward: 0
# State: ('F', 'C', 54, 35), Reward: 0
# State: ('F', 'C', 54, 0), Reward: 0
# State: ('F', 'C', 54, 36), Reward: 0
# State: ('F', 'C', 54, 38), Reward: 0
# State: ('F', 'C', 55, 12), Reward: 0
# State: ('F', 'C', 55, 23), Reward: 0
# State: ('F', 'C', 55, 14), Reward: 0
# State: ('F', 'C', 55, 15), Reward: 1
# State: ('F', 'C', 55, 9), Reward: 0
# State: ('F', 'C', 55, 21), Reward: 1
# State: ('F', 'C', 55, 11), Reward: 0
# State: ('F', 'C', 55, 25), Reward: 0
# State: ('F', 'C', 55, 8), Reward: 0
# State: ('F', 'C', 55, 27), Reward: 0
# State: ('F', 'C', 55, 18), Reward: 0
# State: ('F', 'C', 55, 32), Reward: 0
# State: ('F', 'C', 55, 5), Reward: 0
# State: ('F', 'C', 55, 20), Reward: 0
# State: ('F', 'C', 55, 10), Reward: 0
# State: ('F', 'C', 55, 13), Reward: 0
# State: ('F', 'C', 55, 24), Reward: 0
# State: ('F', 'C', 55, 7), Reward: 0
# State: ('F', 'C', 55, 22), Reward: 0
# State: ('F', 'C', 55, 17), Reward: 1
# State: ('F', 'C', 55, 28), Reward: 1
# State: ('F', 'C', 55, 6), Reward: 0
# State: ('F', 'C', 55, 19), Reward: 0
# State: ('F', 'C', 55, 26), Reward: 0
# State: ('F', 'C', 55, 16), Reward: 0
# State: ('F', 'C', 55, 30), Reward: 0
# State: ('F', 'C', 55, 4), Reward: 0
# State: ('F', 'C', 55, 2), Reward: 0
# State: ('F', 'C', 55, 31), Reward: 0
# State: ('F', 'C', 55, 3), Reward: 0
# State: ('F', 'C', 55, 29), Reward: 0
# State: ('F', 'C', 55, 33), Reward: 0
# State: ('F', 'C', 55, 34), Reward: 0
# State: ('F', 'C', 55, 1), Reward: 0
# State: ('F', 'C', 55, 35), Reward: 0
# State: ('F', 'C', 55, 0), Reward: 0
# State: ('F', 'C', 55, 36), Reward: 0
# State: ('F', 'C', 55, 38), Reward: 0
# State: ('F', 'C', 62, 12), Reward: 0
# State: ('F', 'C', 62, 23), Reward: 0
# State: ('F', 'C', 62, 14), Reward: 0
# State: ('F', 'C', 62, 15), Reward: 0
# State: ('F', 'C', 62, 9), Reward: 0
# State: ('F', 'C', 62, 21), Reward: 0
# State: ('F', 'C', 62, 11), Reward: 0
# State: ('F', 'C', 62, 25), Reward: 0
# State: ('F', 'C', 62, 8), Reward: 0
# State: ('F', 'C', 62, 27), Reward: 0
# State: ('F', 'C', 62, 18), Reward: 1
# State: ('F', 'C', 62, 32), Reward: 0
# State: ('F', 'C', 62, 5), Reward: 1
# State: ('F', 'C', 62, 20), Reward: 0
# State: ('F', 'C', 62, 10), Reward: 0
# State: ('F', 'C', 62, 13), Reward: 0
# State: ('F', 'C', 62, 24), Reward: 0
# State: ('F', 'C', 62, 7), Reward: 0
# State: ('F', 'C', 62, 22), Reward: 0
# State: ('F', 'C', 62, 17), Reward: 0
# State: ('F', 'C', 62, 28), Reward: 0
# State: ('F', 'C', 62, 6), Reward: 0
# State: ('F', 'C', 62, 19), Reward: 0
# State: ('F', 'C', 62, 26), Reward: 0
# State: ('F', 'C', 62, 16), Reward: 0
# State: ('F', 'C', 62, 30), Reward: 0
# State: ('F', 'C', 62, 4), Reward: 0
# State: ('F', 'C', 62, 2), Reward: 0
# State: ('F', 'C', 62, 31), Reward: 0
# State: ('F', 'C', 62, 3), Reward: 0
# State: ('F', 'C', 62, 29), Reward: 0
# State: ('F', 'C', 62, 33), Reward: 0
# State: ('F', 'C', 62, 34), Reward: 0
# State: ('F', 'C', 62, 1), Reward: 0
# State: ('F', 'C', 62, 35), Reward: 0
# State: ('F', 'C', 62, 0), Reward: 0
# State: ('F', 'C', 62, 36), Reward: 0
# State: ('F', 'C', 62, 38), Reward: 0
# State: ('F', 'C', 61, 12), Reward: 0
# State: ('F', 'C', 61, 23), Reward: 0
# State: ('F', 'C', 61, 14), Reward: 0
# State: ('F', 'C', 61, 15), Reward: 0
# State: ('F', 'C', 61, 9), Reward: 1
# State: ('F', 'C', 61, 21), Reward: 0
# State: ('F', 'C', 61, 11), Reward: 0
# State: ('F', 'C', 61, 25), Reward: 0
# State: ('F', 'C', 61, 8), Reward: 0
# State: ('F', 'C', 61, 27), Reward: 0
# State: ('F', 'C', 61, 18), Reward: 0
# State: ('F', 'C', 61, 32), Reward: 0
# State: ('F', 'C', 61, 5), Reward: 1
# State: ('F', 'C', 61, 20), Reward: 0
# State: ('F', 'C', 61, 10), Reward: 0
# State: ('F', 'C', 61, 13), Reward: 0
# State: ('F', 'C', 61, 24), Reward: 0
# State: ('F', 'C', 61, 7), Reward: 0
# State: ('F', 'C', 61, 22), Reward: 0
# State: ('F', 'C', 61, 17), Reward: 0
# State: ('F', 'C', 61, 28), Reward: 0
# State: ('F', 'C', 61, 6), Reward: 0
# State: ('F', 'C', 61, 19), Reward: 0
# State: ('F', 'C', 61, 26), Reward: 0
# State: ('F', 'C', 61, 16), Reward: 0
# State: ('F', 'C', 61, 30), Reward: 0
# State: ('F', 'C', 61, 4), Reward: 0
# State: ('F', 'C', 61, 2), Reward: 0
# State: ('F', 'C', 61, 31), Reward: 1
# State: ('F', 'C', 61, 3), Reward: 0
# State: ('F', 'C', 61, 29), Reward: 0
# State: ('F', 'C', 61, 33), Reward: 1
# State: ('F', 'C', 61, 34), Reward: 0
# State: ('F', 'C', 61, 1), Reward: 0
# State: ('F', 'C', 61, 35), Reward: 0
# State: ('F', 'C', 61, 0), Reward: 0
# State: ('F', 'C', 61, 36), Reward: 0
# State: ('F', 'C', 61, 38), Reward: 0
# State: ('F', 'C', 57, 12), Reward: 1
# State: ('F', 'C', 57, 23), Reward: 0
# State: ('F', 'C', 57, 14), Reward: 0
# State: ('F', 'C', 57, 15), Reward: 0
# State: ('F', 'C', 57, 9), Reward: 0
# State: ('F', 'C', 57, 21), Reward: 0
# State: ('F', 'C', 57, 11), Reward: 0
# State: ('F', 'C', 57, 25), Reward: 1
# State: ('F', 'C', 57, 8), Reward: 0
# State: ('F', 'C', 57, 27), Reward: 0
# State: ('F', 'C', 57, 18), Reward: 0
# State: ('F', 'C', 57, 32), Reward: 0
# State: ('F', 'C', 57, 5), Reward: 0
# State: ('F', 'C', 57, 20), Reward: 0
# State: ('F', 'C', 57, 10), Reward: 0
# State: ('F', 'C', 57, 13), Reward: 0
# State: ('F', 'C', 57, 24), Reward: 0
# State: ('F', 'C', 57, 7), Reward: 0
# State: ('F', 'C', 57, 22), Reward: 0
# State: ('F', 'C', 57, 17), Reward: 0
# State: ('F', 'C', 57, 28), Reward: 0
# State: ('F', 'C', 57, 6), Reward: 0
# State: ('F', 'C', 57, 19), Reward: 0
# State: ('F', 'C', 57, 26), Reward: 0
# State: ('F', 'C', 57, 16), Reward: 1
# State: ('F', 'C', 57, 30), Reward: 0
# State: ('F', 'C', 57, 4), Reward: 1
# State: ('F', 'C', 57, 2), Reward: 0
# State: ('F', 'C', 57, 31), Reward: 0
# State: ('F', 'C', 57, 3), Reward: 0
# State: ('F', 'C', 57, 29), Reward: 0
# State: ('F', 'C', 57, 33), Reward: 0
# State: ('F', 'C', 57, 34), Reward: 0
# State: ('F', 'C', 57, 1), Reward: 0
# State: ('F', 'C', 57, 35), Reward: 0
# State: ('F', 'C', 57, 0), Reward: 0
# State: ('F', 'C', 57, 36), Reward: 0
# State: ('F', 'C', 57, 38), Reward: 0
# State: ('F', 'C', 58, 12), Reward: 0
# State: ('F', 'C', 58, 23), Reward: 0
# State: ('F', 'C', 58, 14), Reward: 0
# State: ('F', 'C', 58, 15), Reward: 1
# State: ('F', 'C', 58, 9), Reward: 0
# State: ('F', 'C', 58, 21), Reward: 0
# State: ('F', 'C', 58, 11), Reward: 0
# State: ('F', 'C', 58, 25), Reward: 1
# State: ('F', 'C', 58, 8), Reward: 1
# State: ('F', 'C', 58, 27), Reward: 0
# State: ('F', 'C', 58, 18), Reward: 0
# State: ('F', 'C', 58, 32), Reward: 0
# State: ('F', 'C', 58, 5), Reward: 0
# State: ('F', 'C', 58, 20), Reward: 0
# State: ('F', 'C', 58, 10), Reward: 0
# State: ('F', 'C', 58, 13), Reward: 0
# State: ('F', 'C', 58, 24), Reward: 0
# State: ('F', 'C', 58, 7), Reward: 0
# State: ('F', 'C', 58, 22), Reward: 0
# State: ('F', 'C', 58, 17), Reward: 0
# State: ('F', 'C', 58, 28), Reward: 0
# State: ('F', 'C', 58, 6), Reward: 0
# State: ('F', 'C', 58, 19), Reward: 0
# State: ('F', 'C', 58, 26), Reward: 0
# State: ('F', 'C', 58, 16), Reward: 1
# State: ('F', 'C', 58, 30), Reward: 0
# State: ('F', 'C', 58, 4), Reward: 1
# State: ('F', 'C', 58, 2), Reward: 0
# State: ('F', 'C', 58, 31), Reward: 0
# State: ('F', 'C', 58, 3), Reward: 0
# State: ('F', 'C', 58, 29), Reward: 0
# State: ('F', 'C', 58, 33), Reward: 0
# State: ('F', 'C', 58, 34), Reward: 0
# State: ('F', 'C', 58, 1), Reward: 0
# State: ('F', 'C', 58, 35), Reward: 0
# State: ('F', 'C', 58, 0), Reward: 0
# State: ('F', 'C', 58, 36), Reward: 0
# State: ('F', 'C', 58, 38), Reward: 0
# State: ('F', 'C', 59, 12), Reward: 0
# State: ('F', 'C', 59, 23), Reward: 0
# State: ('F', 'C', 59, 14), Reward: 0
# State: ('F', 'C', 59, 15), Reward: 0
# State: ('F', 'C', 59, 9), Reward: 0
# State: ('F', 'C', 59, 21), Reward: 0
# State: ('F', 'C', 59, 11), Reward: 0
# State: ('F', 'C', 59, 25), Reward: 0
# State: ('F', 'C', 59, 8), Reward: 0
# State: ('F', 'C', 59, 27), Reward: 0
# State: ('F', 'C', 59, 18), Reward: 0
# State: ('F', 'C', 59, 32), Reward: 0
# State: ('F', 'C', 59, 5), Reward: 0
# State: ('F', 'C', 59, 20), Reward: 0
# State: ('F', 'C', 59, 10), Reward: 0
# State: ('F', 'C', 59, 13), Reward: 0
# State: ('F', 'C', 59, 24), Reward: 0
# State: ('F', 'C', 59, 7), Reward: 0
# State: ('F', 'C', 59, 22), Reward: 0
# State: ('F', 'C', 59, 17), Reward: 0
# State: ('F', 'C', 59, 28), Reward: 0
# State: ('F', 'C', 59, 6), Reward: 1
# State: ('F', 'C', 59, 19), Reward: 0
# State: ('F', 'C', 59, 26), Reward: 0
# State: ('F', 'C', 59, 16), Reward: 0
# State: ('F', 'C', 59, 30), Reward: 1
# State: ('F', 'C', 59, 4), Reward: 0
# State: ('F', 'C', 59, 2), Reward: 0
# State: ('F', 'C', 59, 31), Reward: 0
# State: ('F', 'C', 59, 3), Reward: 0
# State: ('F', 'C', 59, 29), Reward: 0
# State: ('F', 'C', 59, 33), Reward: 0
# State: ('F', 'C', 59, 34), Reward: 0
# State: ('F', 'C', 59, 1), Reward: 0
# State: ('F', 'C', 59, 35), Reward: 0
# State: ('F', 'C', 59, 0), Reward: 0
# State: ('F', 'C', 59, 36), Reward: 0
# State: ('F', 'C', 59, 38), Reward: 0
# State: ('F', 'C', 56, 12), Reward: 0
# State: ('F', 'C', 56, 23), Reward: 0
# State: ('F', 'C', 56, 14), Reward: 0
# State: ('F', 'C', 56, 15), Reward: 0
# State: ('F', 'C', 56, 9), Reward: 0
# State: ('F', 'C', 56, 21), Reward: 0
# State: ('F', 'C', 56, 11), Reward: 0
# State: ('F', 'C', 56, 25), Reward: 0
# State: ('F', 'C', 56, 8), Reward: 1
# State: ('F', 'C', 56, 27), Reward: 0
# State: ('F', 'C', 56, 18), Reward: 0
# State: ('F', 'C', 56, 32), Reward: 0
# State: ('F', 'C', 56, 5), Reward: 0
# State: ('F', 'C', 56, 20), Reward: 0
# State: ('F', 'C', 56, 10), Reward: 0
# State: ('F', 'C', 56, 13), Reward: 0
# State: ('F', 'C', 56, 24), Reward: 0
# State: ('F', 'C', 56, 7), Reward: 0
# State: ('F', 'C', 56, 22), Reward: 0
# State: ('F', 'C', 56, 17), Reward: 0
# State: ('F', 'C', 56, 28), Reward: 0
# State: ('F', 'C', 56, 6), Reward: 0
# State: ('F', 'C', 56, 19), Reward: 0
# State: ('F', 'C', 56, 26), Reward: 0
# State: ('F', 'C', 56, 16), Reward: 0
# State: ('F', 'C', 56, 30), Reward: 0
# State: ('F', 'C', 56, 4), Reward: 0
# State: ('F', 'C', 56, 2), Reward: 1
# State: ('F', 'C', 56, 31), Reward: 0
# State: ('F', 'C', 56, 3), Reward: 0
# State: ('F', 'C', 56, 29), Reward: 0
# State: ('F', 'C', 56, 33), Reward: 0
# State: ('F', 'C', 56, 34), Reward: 0
# State: ('F', 'C', 56, 1), Reward: 0
# State: ('F', 'C', 56, 35), Reward: 0
# State: ('F', 'C', 56, 0), Reward: 0
# State: ('F', 'C', 56, 36), Reward: 0
# State: ('F', 'C', 56, 38), Reward: 0
# State: ('F', 'C', 60, 12), Reward: 0
# State: ('F', 'C', 60, 23), Reward: 0
# State: ('F', 'C', 60, 14), Reward: 0
# State: ('F', 'C', 60, 15), Reward: 0
# State: ('F', 'C', 60, 9), Reward: 0
# State: ('F', 'C', 60, 21), Reward: 0
# State: ('F', 'C', 60, 11), Reward: 0
# State: ('F', 'C', 60, 25), Reward: 0
# State: ('F', 'C', 60, 8), Reward: 0
# State: ('F', 'C', 60, 27), Reward: 0
# State: ('F', 'C', 60, 18), Reward: 1
# State: ('F', 'C', 60, 32), Reward: 0
# State: ('F', 'C', 60, 5), Reward: 0
# State: ('F', 'C', 60, 20), Reward: 0
# State: ('F', 'C', 60, 10), Reward: 0
# State: ('F', 'C', 60, 13), Reward: 0
# State: ('F', 'C', 60, 24), Reward: 0
# State: ('F', 'C', 60, 7), Reward: 0
# State: ('F', 'C', 60, 22), Reward: 0
# State: ('F', 'C', 60, 17), Reward: 1
# State: ('F', 'C', 60, 28), Reward: 0
# State: ('F', 'C', 60, 6), Reward: 0
# State: ('F', 'C', 60, 19), Reward: 0
# State: ('F', 'C', 60, 26), Reward: 0
# State: ('F', 'C', 60, 16), Reward: 0
# State: ('F', 'C', 60, 30), Reward: 1
# State: ('F', 'C', 60, 4), Reward: 0
# State: ('F', 'C', 60, 2), Reward: 0
# State: ('F', 'C', 60, 31), Reward: 0
# State: ('F', 'C', 60, 3), Reward: 0
# State: ('F', 'C', 60, 29), Reward: 0
# State: ('F', 'C', 60, 33), Reward: 0
# State: ('F', 'C', 60, 34), Reward: 0
# State: ('F', 'C', 60, 1), Reward: 0
# State: ('F', 'C', 60, 35), Reward: 0
# State: ('F', 'C', 60, 0), Reward: 0
# State: ('F', 'C', 60, 36), Reward: 0
# State: ('F', 'C', 60, 38), Reward: 0
# State: ('F', 'C', 63, 12), Reward: 0
# State: ('F', 'C', 63, 23), Reward: 0
# State: ('F', 'C', 63, 14), Reward: 0
# State: ('F', 'C', 63, 15), Reward: 0
# State: ('F', 'C', 63, 9), Reward: 0
# State: ('F', 'C', 63, 21), Reward: 0
# State: ('F', 'C', 63, 11), Reward: 1
# State: ('F', 'C', 63, 25), Reward: 0
# State: ('F', 'C', 63, 8), Reward: 0
# State: ('F', 'C', 63, 27), Reward: 0
# State: ('F', 'C', 63, 18), Reward: 0
# State: ('F', 'C', 63, 32), Reward: 0
# State: ('F', 'C', 63, 5), Reward: 0
# State: ('F', 'C', 63, 20), Reward: 1
# State: ('F', 'C', 63, 10), Reward: 0
# State: ('F', 'C', 63, 13), Reward: 1
# State: ('F', 'C', 63, 24), Reward: 0
# State: ('F', 'C', 63, 7), Reward: 0
# State: ('F', 'C', 63, 22), Reward: 0
# State: ('F', 'C', 63, 17), Reward: 0
# State: ('F', 'C', 63, 28), Reward: 0
# State: ('F', 'C', 63, 6), Reward: 0
# State: ('F', 'C', 63, 19), Reward: 0
# State: ('F', 'C', 63, 26), Reward: 0
# State: ('F', 'C', 63, 16), Reward: 0
# State: ('F', 'C', 63, 30), Reward: 1
# State: ('F', 'C', 63, 4), Reward: 0
# State: ('F', 'C', 63, 2), Reward: 0
# State: ('F', 'C', 63, 31), Reward: 0
# State: ('F', 'C', 63, 3), Reward: 0
# State: ('F', 'C', 63, 29), Reward: 0
# State: ('F', 'C', 63, 33), Reward: 0
# State: ('F', 'C', 63, 34), Reward: 0
# State: ('F', 'C', 63, 1), Reward: 0
# State: ('F', 'C', 63, 35), Reward: 0
# State: ('F', 'C', 63, 0), Reward: 0
# State: ('F', 'C', 63, 36), Reward: 0
# State: ('F', 'C', 63, 38), Reward: 0

# %% [markdown]
# # ACTIONS

# %%
actions = merged_data['SubLine_Sent'].unique()

# %% [markdown]
# # REWARDS

# %% [markdown]
# # Q-AGENT

# %%
class QLearningAgent:
    def __init__(self, state_size, action_size, learning_rate=0.1, discount_factor=0.9, epsilon=0.1):
        self.state_size = state_size
        self.action_size = action_size
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor
        self.epsilon = epsilon
        self.Q_table = np.zeros((state_size, action_size))  

    def map_state_to_index(self, state):
        # Map state to index
        # Assuming state is a list or a tuple
        state_hash = hash(tuple(state))
        return state_hash % self.state_size

    def map_action_to_index(self, action):
        # Map action to index
        # Assuming action is an integer
        return int(action) % self.action_size

    def choose_action(self, state):
        if np.random.rand() < self.epsilon:
            # Explore: choose a random action
            return np.random.randint(self.action_size)
        else:
            # Exploit: choose the action with the highest Q-value for the current state
            state_index = self.map_state_to_index(state)
            return np.argmax(self.Q_table[state_index])

    def update_q_table(self, state, action, reward, next_state):
        # Map state and action to indices
        state_index = self.map_state_to_index(state)
        action_index = self.map_action_to_index(action)
        
        # Q-learning update rule
        next_state_index = self.map_state_to_index(next_state)
        td_target = reward + self.discount_factor * np.max(self.Q_table[next_state_index])
        td_error = td_target - self.Q_table[state_index, action_index]
        self.Q_table[state_index, action_index] += self.learning_rate * td_error

    def train(self, state, action, reward, next_state):
        self.update_q_table(state, action, reward, next_state)

    def get_q_table(self):
        return self.Q_table

# %% [markdown]
# # TRAINING OF Q-AGENT

# %%
state_size = len(states)  # Assuming states is a list of states
action_size = len(actions)  # Assuming actions is a list of unique actions

# Initialize the Q-learning agent
agent = QLearningAgent(state_size, action_size, learning_rate=0.1, discount_factor=0.9, epsilon=0.1)

# Define your training loop
num_episodes = 1000  # Number of training episodes

for episode in range(num_episodes):
    # Iterate over state-action pairs
    for i in range(len(states) - 1):
        # Get current state and action
        state = states[i]
        state_index = hash(tuple(state)) % len(states)
        action = merged_data.loc[state_index, 'SubLine_Sent']
        reward = merged_data.loc[state_index, 'Reward']
       
        # Get next state
        next_state = states[i + 1]
        
        # Train the agent
        agent.train(state, action, reward, next_state)

# Get the learned Q-table
Q_table = agent.get_q_table()
print("Q-Table:", Q_table)
# Out:
# Q-Table: [[0.         0.         0.73494989]
#  [0.         0.         0.        ]
#  [0.5423535  0.         0.        ]
#  ...
#  [1.45434786 0.         0.        ]
#  [0.         0.         0.        ]
#  [0.         0.89727918 0.        ]]

# %% [markdown]
# The Q_table printed in the code represents the learned Q-values for each state-action pair after training the Q-learning agent. Each entry in the Q-table represents the expected cumulative reward the agent expects to receive when taking a specific action from a specific state.
#
# In a Q-table, each row corresponds to a state, and each column corresponds to an action. So, the value at row i and column j (i.e., Q_table[i, j]) represents the Q-value for taking action j from state i.
#
# When you print the Q_table, you'll see a matrix where each row corresponds to a state, and each column corresponds to an action.
#
# So, for instance, Q_table[0, 2]=0 indicates that the Q-value for taking action 2 from the first state is 0. Similarly, Q_table[2, 1] indicates that the Q-value for taking action 1 from the third state is 0.0. Similarly, Q_table[0,1]=1 means Q-value for taking action 1 from the first state is 1
#
# This Q-table is what the agent has learned from its interactions with the environment during training. These Q-values guide the agent's decision-making process during the exploitation phase, where it selects actions based on the highest Q-value for each state.

# %%
print(f'Dimensions of Q-table: {Q_table.shape}')
# Out:
# Dimensions of Q-table: (6992, 3)

# %% [markdown]
# # NEW SCENARIOS

# %%
merged_data.iloc[2012:2013][['Gender', 'Type', 'Age', 'Tenure']].values.tolist()
# Out:
# [['F', 'C', 23, 19]]

# %%
merged_data.iloc[5003:5004][['Gender', 'Type', 'Age', 'Tenure']].values.tolist()
# Out:
# [['F', 'B', 53, 20]]

# %%
merged_data.iloc[3788:3789][['Gender', 'Type', 'Age', 'Tenure']].values.tolist()
# Out:
# [['M', 'C', 28, 18]]

# %%
# Assuming 'new_state' is the new state of the environment
new_state = merged_data.iloc[9053:9054][['Gender', 'Type', 'Age', 'Tenure']].values.tolist()

# Convert nested lists to tuples
new_state = [tuple(item) if isinstance(item, list) else item for item in new_state]
new_state = tuple(new_state)  # Convert the list representing the state to a tuple
new_state_index = agent.map_state_to_index(new_state)  # Map state to index
q_values = Q_table[new_state_index]  # Retrieve Q-values for the new state
action = np.argmax(q_values)  # Select action with the highest Q-value
print(action)
# Out:
# 1

# %% [markdown]
# ## Multiple scenarios/states

# %%
# List of new states
new_states = [
    merged_data.iloc[5003:5004][['Gender', 'Type', 'Age', 'Tenure']].values.tolist(),
    merged_data.iloc[3788:3789][['Gender', 'Type', 'Age', 'Tenure']].values.tolist(),
]

# Obtain action for each new state
actions = []
for new_state in new_states:
    # Convert nested lists to tuples
    new_state = [tuple(item) if isinstance(item, list) else item for item in new_state]
    new_state = tuple(new_state)  # Convert the list representing the state to a tuple
    
    # Map state to index and retrieve action
    new_state_index = agent.map_state_to_index(new_state)
    q_values = Q_table[new_state_index]
    action = np.argmax(q_values)
    
    # Append action to the list of actions
    actions.append(action)

# Now 'actions' contains the actions selected by the agent for each new state
print(actions)
# Out:
# [0, 2]

# %%
# Assuming 'actions' contains the indices of predicted actions
subject_lines = ['Subject line 1', 'Subject line 2', 'Subject line 3']

# Print the predicted subject lines
for action_index in actions:
    predicted_subject_line = subject_lines[action_index]
    print(f"The subject line predicted by the Q-agent is {predicted_subject_line}.")
# Out:
# The subject line predicted by the Q-agent is Subject line 1.
# The subject line predicted by the Q-agent is Subject line 3.

# %% [markdown]
# # DOWNLOAD

# %%
# DOWNLOAD THE AGENT
# Assuming Q_table is your Q-table numpy array
# Save Q-table as a pickle file
with open('q_table.pkl', 'wb') as f:
    pickle.dump(Q_table, f)
